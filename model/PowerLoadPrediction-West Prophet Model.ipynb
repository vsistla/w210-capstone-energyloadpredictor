# %% [markdown]
#  # Power Load Prediction for West Zone - Prophet Model

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
power_data_west = pd.read_csv("west_interval_data_01-29-2019_01-27-2021.csv")

# %%
power_data_west['End Date Time'] = pd.to_datetime(power_data_west['End Date Time'], infer_datetime_format=True)
indexedDataset = power_data_west.set_index(['End Date Time'])

# %%
plot_df_west = pd.DataFrame(power_data_west, columns=['Peak Demand', 'Avg. Temperature', 'End Date Time'])

# %%
plot_df_west['End Date Time'].min()
# Out:
# Timestamp('2019-01-29 00:15:00')

# %%
plot_df_west['End Date Time'].max()
# Out:
# Timestamp('2022-01-27 00:00:00')

# %%
power_data_west['month'] = power_data_west['End Date Time'].dt.strftime('%b')

# %%
power_data_west['day_of_week'] = power_data_west['End Date Time'].dt.day_name()

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

date_range = pd.date_range(start='2019-01-01', end='2022-01-27')

cal = calendar()
holidays = cal.holidays(start=date_range.min(), end=date_range.max())

power_data_west['holiday'] = power_data_west['End Date Time'].dt.date.astype('datetime64').isin(holidays)

# %%
power_data_west.head(10)
# Out:
#   Service Agreement Start Date Time       End Date Time  Usage Usage Unit  \
# 0              west    1/29/19 0:00 2019-01-29 00:15:00  211.2        KWH
# 1              west    1/29/19 0:15 2019-01-29 00:30:00  210.4        KWH
# 2              west    1/29/19 0:30 2019-01-29 00:45:00  208.0        KWH
# 3              west    1/29/19 0:45 2019-01-29 01:00:00  212.0        KWH
# 4              west    1/29/19 1:00 2019-01-29 01:15:00  203.2        KWH
# 5              west    1/29/19 1:15 2019-01-29 01:30:00  205.6        KWH
# 6              west    1/29/19 1:30 2019-01-29 01:45:00  205.6        KWH
# 7              west    1/29/19 1:45 2019-01-29 02:00:00  208.8        KWH
# 8              west    1/29/19 2:00 2019-01-29 02:15:00  217.6        KWH
# 9              west    1/29/19 2:15 2019-01-29 02:30:00  229.6        KWH
#
#    Cost  Currency Unit  Avg. Temperature Temperature Unit Event Flags  \
# 0   NaN            NaN              54.0       FAHRENHEIT         NaN
# 1   NaN            NaN              54.0       FAHRENHEIT         NaN
# 2   NaN            NaN              54.0       FAHRENHEIT         NaN
# 3   NaN            NaN              54.0       FAHRENHEIT         NaN
# 4   NaN            NaN              55.0       FAHRENHEIT         NaN
# 5   NaN            NaN              55.0       FAHRENHEIT         NaN
# 6   NaN            NaN              55.0       FAHRENHEIT         NaN
# 7   NaN            NaN              55.0       FAHRENHEIT         NaN
# 8   NaN            NaN              55.0       FAHRENHEIT         NaN
# 9   NaN            NaN              55.0       FAHRENHEIT         NaN
#
#    Peak Demand Demand Unit month day_of_week  holiday
# 0        844.8          KW   Jan     Tuesday    False
# 1        841.6          KW   Jan     Tuesday    False
# 2        832.0          KW   Jan     Tuesday    False
# 3        848.0          KW   Jan     Tuesday    False
# 4        812.8          KW   Jan     Tuesday    False
# 5        822.4          KW   Jan     Tuesday    False
# 6        822.4          KW   Jan     Tuesday    False
# 7        835.2          KW   Jan     Tuesday    False
# 8        870.4          KW   Jan     Tuesday    False
# 9        918.4          KW   Jan     Tuesday    False

# %%
power_data_west.tail(10)
# Out:
#        Service Agreement Start Date Time       End Date Time  Usage  \
# 104726              west   1/26/22 21:30 2022-01-26 21:45:00  284.0
# 104727              west   1/26/22 21:45 2022-01-26 22:00:00  288.8
# 104728              west   1/26/22 22:00 2022-01-26 22:15:00  301.6
# 104729              west   1/26/22 22:15 2022-01-26 22:30:00  280.0
# 104730              west   1/26/22 22:30 2022-01-26 22:45:00  296.8
# 104731              west   1/26/22 22:45 2022-01-26 23:00:00  282.4
# 104732              west   1/26/22 23:00 2022-01-26 23:15:00  288.8
# 104733              west   1/26/22 23:15 2022-01-26 23:30:00  289.6
# 104734              west   1/26/22 23:30 2022-01-26 23:45:00  294.4
# 104735              west   1/26/22 23:45 2022-01-27 00:00:00  290.4
#
#        Usage Unit  Cost  Currency Unit  Avg. Temperature Temperature Unit  \
# 104726        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104727        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104728        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104729        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104730        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104731        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104732        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104733        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104734        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104735        KWH   NaN            NaN              51.0       FAHRENHEIT
#
#        Event Flags  Peak Demand Demand Unit month day_of_week  holiday
# 104726         NaN       1136.0          KW   Jan   Wednesday    False
# 104727         NaN       1155.2          KW   Jan   Wednesday    False
# 104728         NaN       1206.4          KW   Jan   Wednesday    False
# 104729         NaN       1120.0          KW   Jan   Wednesday    False
# 104730         NaN       1187.2          KW   Jan   Wednesday    False
# 104731         NaN       1129.6          KW   Jan   Wednesday    False
# 104732         NaN       1155.2          KW   Jan   Wednesday    False
# 104733         NaN       1158.4          KW   Jan   Wednesday    False
# 104734         NaN       1177.6          KW   Jan   Wednesday    False
# 104735         NaN       1161.6          KW   Jan    Thursday    False

# %%
power_data_west.describe()
# Out:
#                Usage  Cost  Currency Unit  Avg. Temperature    Peak Demand
# count  104724.000000   0.0            0.0     104716.000000  104724.000000
# mean      309.636443   NaN            NaN         67.377211    1238.545770
# std        75.557612   NaN            NaN         16.591545     302.230457
# min         0.000000   NaN            NaN         29.000000       0.000000
# 25%       252.000000   NaN            NaN         54.000000    1008.000000
# 50%       308.000000   NaN            NaN         66.000000    1232.000000
# 75%       368.000000   NaN            NaN         79.000000    1472.000000
# max       531.200000   NaN            NaN        114.000000    2124.800000

# %%
power_data_west.shape
# Out:
# (104736, 15)

# %%
power_data_west.dtypes
# Out:
# Service Agreement            object
# Start Date Time              object
# End Date Time        datetime64[ns]
# Usage                       float64
# Usage Unit                   object
# Cost                        float64
# Currency Unit               float64
# Avg. Temperature            float64
# Temperature Unit             object
# Event Flags                  object
# Peak Demand                 float64
# Demand Unit                  object
# month                        object
# day_of_week                  object
# holiday                        bool
# dtype: object

# %%
#For checking missing values in dataset
power_data_west.isna().sum()
# Out:
# Service Agreement         0
# Start Date Time           0
# End Date Time             0
# Usage                    12
# Usage Unit               12
# Cost                 104736
# Currency Unit        104736
# Avg. Temperature         20
# Temperature Unit          0
# Event Flags          104730
# Peak Demand              12
# Demand Unit              12
# month                     0
# day_of_week               0
# holiday                   0
# dtype: int64

# %%
power_data_west.fillna(method='ffill',inplace=True)
power_data_west.isna().sum()
# Out:
# Service Agreement         0
# Start Date Time           0
# End Date Time             0
# Usage                     0
# Usage Unit                0
# Cost                 104736
# Currency Unit        104736
# Avg. Temperature          0
# Temperature Unit          0
# Event Flags            3840
# Peak Demand               0
# Demand Unit               0
# month                     0
# day_of_week               0
# holiday                   0
# dtype: int64

# %%
zero_usage_df = power_data_west.loc[power_data_west['Peak Demand'] == 0]
zero_usage_df.count()
# Out:
# Service Agreement    50
# Start Date Time      50
# End Date Time        50
# Usage                50
# Usage Unit           50
# Cost                  0
# Currency Unit         0
# Avg. Temperature     50
# Temperature Unit     50
# Event Flags          50
# Peak Demand          50
# Demand Unit          50
# month                50
# day_of_week          50
# holiday              50
# dtype: int64

# %% [markdown]
# dataset.kW.plot()

# %% [markdown]
# ## Prophet Timeseries Model

# %%
prophet_data = power_data_west[(power_data_west['End Date Time'] > '2019-01-01') & (power_data_west['End Date Time'] < '2022-02-01')]

# %%
prophet_data.head(10)
# Out:
#   Service Agreement Start Date Time       End Date Time  Usage Usage Unit  \
# 0              west    1/29/19 0:00 2019-01-29 00:15:00  211.2        KWH
# 1              west    1/29/19 0:15 2019-01-29 00:30:00  210.4        KWH
# 2              west    1/29/19 0:30 2019-01-29 00:45:00  208.0        KWH
# 3              west    1/29/19 0:45 2019-01-29 01:00:00  212.0        KWH
# 4              west    1/29/19 1:00 2019-01-29 01:15:00  203.2        KWH
# 5              west    1/29/19 1:15 2019-01-29 01:30:00  205.6        KWH
# 6              west    1/29/19 1:30 2019-01-29 01:45:00  205.6        KWH
# 7              west    1/29/19 1:45 2019-01-29 02:00:00  208.8        KWH
# 8              west    1/29/19 2:00 2019-01-29 02:15:00  217.6        KWH
# 9              west    1/29/19 2:15 2019-01-29 02:30:00  229.6        KWH
#
#    Cost  Currency Unit  Avg. Temperature Temperature Unit Event Flags  \
# 0   NaN            NaN              54.0       FAHRENHEIT         NaN
# 1   NaN            NaN              54.0       FAHRENHEIT         NaN
# 2   NaN            NaN              54.0       FAHRENHEIT         NaN
# 3   NaN            NaN              54.0       FAHRENHEIT         NaN
# 4   NaN            NaN              55.0       FAHRENHEIT         NaN
# 5   NaN            NaN              55.0       FAHRENHEIT         NaN
# 6   NaN            NaN              55.0       FAHRENHEIT         NaN
# 7   NaN            NaN              55.0       FAHRENHEIT         NaN
# 8   NaN            NaN              55.0       FAHRENHEIT         NaN
# 9   NaN            NaN              55.0       FAHRENHEIT         NaN
#
#    Peak Demand Demand Unit month day_of_week  holiday
# 0        844.8          KW   Jan     Tuesday    False
# 1        841.6          KW   Jan     Tuesday    False
# 2        832.0          KW   Jan     Tuesday    False
# 3        848.0          KW   Jan     Tuesday    False
# 4        812.8          KW   Jan     Tuesday    False
# 5        822.4          KW   Jan     Tuesday    False
# 6        822.4          KW   Jan     Tuesday    False
# 7        835.2          KW   Jan     Tuesday    False
# 8        870.4          KW   Jan     Tuesday    False
# 9        918.4          KW   Jan     Tuesday    False

# %%
prophet_data.tail(10)
# Out:
#        Service Agreement Start Date Time       End Date Time  Usage  \
# 104726              west   1/26/22 21:30 2022-01-26 21:45:00  284.0
# 104727              west   1/26/22 21:45 2022-01-26 22:00:00  288.8
# 104728              west   1/26/22 22:00 2022-01-26 22:15:00  301.6
# 104729              west   1/26/22 22:15 2022-01-26 22:30:00  280.0
# 104730              west   1/26/22 22:30 2022-01-26 22:45:00  296.8
# 104731              west   1/26/22 22:45 2022-01-26 23:00:00  282.4
# 104732              west   1/26/22 23:00 2022-01-26 23:15:00  288.8
# 104733              west   1/26/22 23:15 2022-01-26 23:30:00  289.6
# 104734              west   1/26/22 23:30 2022-01-26 23:45:00  294.4
# 104735              west   1/26/22 23:45 2022-01-27 00:00:00  290.4
#
#        Usage Unit  Cost  Currency Unit  Avg. Temperature Temperature Unit  \
# 104726        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104727        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104728        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104729        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104730        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104731        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104732        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104733        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104734        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104735        KWH   NaN            NaN              51.0       FAHRENHEIT
#
#              Event Flags  Peak Demand Demand Unit month day_of_week  holiday
# 104726  Daylight Savings       1136.0          KW   Jan   Wednesday    False
# 104727  Daylight Savings       1155.2          KW   Jan   Wednesday    False
# 104728  Daylight Savings       1206.4          KW   Jan   Wednesday    False
# 104729  Daylight Savings       1120.0          KW   Jan   Wednesday    False
# 104730  Daylight Savings       1187.2          KW   Jan   Wednesday    False
# 104731  Daylight Savings       1129.6          KW   Jan   Wednesday    False
# 104732  Daylight Savings       1155.2          KW   Jan   Wednesday    False
# 104733  Daylight Savings       1158.4          KW   Jan   Wednesday    False
# 104734  Daylight Savings       1177.6          KW   Jan   Wednesday    False
# 104735  Daylight Savings       1161.6          KW   Jan    Thursday    False

# %%
prophet_data_mod = prophet_data[['End Date Time','Peak Demand', 'Avg. Temperature']].copy()

# %%
prophet_data_mod.head(10)
# Out:
#         End Date Time  Peak Demand  Avg. Temperature
# 0 2019-01-29 00:15:00        844.8              54.0
# 1 2019-01-29 00:30:00        841.6              54.0
# 2 2019-01-29 00:45:00        832.0              54.0
# 3 2019-01-29 01:00:00        848.0              54.0
# 4 2019-01-29 01:15:00        812.8              55.0
# 5 2019-01-29 01:30:00        822.4              55.0
# 6 2019-01-29 01:45:00        822.4              55.0
# 7 2019-01-29 02:00:00        835.2              55.0
# 8 2019-01-29 02:15:00        870.4              55.0
# 9 2019-01-29 02:30:00        918.4              55.0

# %%
prophet_data_mod.rename(columns={'End Date Time':'ds','Avg. Temperature':'add1', 'Peak Demand':'y'}, inplace=True)

# %%
prophet_data_mod.head(10)
# Out:
#                    ds      y  add1
# 0 2019-01-29 00:15:00  844.8  54.0
# 1 2019-01-29 00:30:00  841.6  54.0
# 2 2019-01-29 00:45:00  832.0  54.0
# 3 2019-01-29 01:00:00  848.0  54.0
# 4 2019-01-29 01:15:00  812.8  55.0
# 5 2019-01-29 01:30:00  822.4  55.0
# 6 2019-01-29 01:45:00  822.4  55.0
# 7 2019-01-29 02:00:00  835.2  55.0
# 8 2019-01-29 02:15:00  870.4  55.0
# 9 2019-01-29 02:30:00  918.4  55.0

# %%
X_train = prophet_data_mod[(prophet_data_mod['ds'] > '2019-01-01') & (prophet_data_mod['ds'] < '2021-01-01')]

X_test = prophet_data_mod[(prophet_data_mod['ds'] > '2021-01-01') ]

# %%
X_train.head(10)
# Out:
#                    ds      y  add1
# 0 2019-01-29 00:15:00  844.8  54.0
# 1 2019-01-29 00:30:00  841.6  54.0
# 2 2019-01-29 00:45:00  832.0  54.0
# 3 2019-01-29 01:00:00  848.0  54.0
# 4 2019-01-29 01:15:00  812.8  55.0
# 5 2019-01-29 01:30:00  822.4  55.0
# 6 2019-01-29 01:45:00  822.4  55.0
# 7 2019-01-29 02:00:00  835.2  55.0
# 8 2019-01-29 02:15:00  870.4  55.0
# 9 2019-01-29 02:30:00  918.4  55.0

# %%
X_train.shape
# Out:
# (67487, 3)

# %%
X_test.head(10)
# Out:
#                        ds      y  add1
# 67488 2021-01-01 00:15:00  812.8  40.0
# 67489 2021-01-01 00:30:00  800.0  40.0
# 67490 2021-01-01 00:45:00  841.6  40.0
# 67491 2021-01-01 01:00:00  822.4  40.0
# 67492 2021-01-01 01:15:00  793.6  40.0
# 67493 2021-01-01 01:30:00  828.8  40.0
# 67494 2021-01-01 01:45:00  816.0  40.0
# 67495 2021-01-01 02:00:00  793.6  40.0
# 67496 2021-01-01 02:15:00  809.6  40.0
# 67497 2021-01-01 02:30:00  796.8  40.0

# %%
X_test.shape
# Out:
# (37248, 3)

# %%
X_test_copy = X_test.copy()
X_test_copy.drop(columns="y")
# Out:
#                         ds  add1
# 67488  2021-01-01 00:15:00  40.0
# 67489  2021-01-01 00:30:00  40.0
# 67490  2021-01-01 00:45:00  40.0
# 67491  2021-01-01 01:00:00  40.0
# 67492  2021-01-01 01:15:00  40.0
# ...                    ...   ...
# 104731 2022-01-26 23:00:00  51.0
# 104732 2022-01-26 23:15:00  51.0
# 104733 2022-01-26 23:30:00  51.0
# 104734 2022-01-26 23:45:00  51.0
# 104735 2022-01-27 00:00:00  51.0
#
# [37248 rows x 2 columns]

# %%
import pandas as pd
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
print('Model Training Started')

prophet_model = Prophet(yearly_seasonality=True)
prophet_model.add_regressor('add1')
prophet_model.fit(X_train)

print('Model Training Completed')
# Out:
# Model Training Started
# /Users/diveshkumar/Library/Python/3.8/lib/python/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -1926.26
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        151608     0.0322635       56484.1           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        156277     0.0235731       10908.9           1           1      226
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        156928     0.0150499       9018.67           1           1      339
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        157688    0.00950213       5027.57           1           1      444
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499        157991    0.00416118       7473.08           1           1      548
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599     Model Training Completed
#    158248    0.00295166       2935.92           1           1      657
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699        159263    0.00288267       2421.13           1           1      763
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799        159384    0.00914054        3704.2           1           1      870
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899        159464    0.00476942       2691.39           1           1      975
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999        159494    0.00182919       1724.92           1           1     1086
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        159753     0.0102356       6037.34           1           1     1194
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        159825    0.00541731       2720.09           1           1     1302
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        159846   0.000248332        3145.7      0.3421      0.3421     1411
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        159937    0.00438938       2043.89           1           1     1516
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499        159994    0.00419433       1864.61           1           1     1625
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        160085     0.0036231       2647.24           1           1     1737
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699        160107   0.000908063       1347.29           1           1     1847
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799        160119    0.00113475       1347.38      0.2671           1     1956
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899        160128    0.00750119       1771.75       1.533      0.1533     2067
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999        160139   0.000181563       1623.87      0.2968      0.2968     2182
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099        160146     0.0018188       1897.24           1           1     2297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199        160151   0.000179949       515.529           1           1     2404
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299        160170    0.00169945       1430.74       0.462       0.962     2517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399        160222     0.0010395       1590.69      0.4759     0.04759     2629
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499        160225   0.000170496       396.005      0.9932      0.9932     2741
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599        160247     0.0254382       1327.06           1           1     2854
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699        160256    0.00214051       647.702           1           1     2962
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799        160263   0.000157208        319.96           1           1     3074
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899        160271   0.000632044       686.204      0.9136      0.9136     3179
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999        160274    0.00444213       2669.11           1           1     3292
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099        160279    0.00254342          1665      0.9803      0.9803     3400
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3126        160283   1.76492e-05       257.432   1.258e-07       0.001     3479  LS failed, Hessian reset
#     3199        160285   0.000472428         643.1           1           1     3564
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3246        160285    5.6193e-06       168.824   6.171e-08       0.001     3667  LS failed, Hessian reset
#     3299        160286   0.000412595       382.907           1           1     3726
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399        160289   0.000658831       566.188           1           1     3840
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499        160294   0.000780643       560.261           1           1     3950
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599        160294   4.15998e-05       193.226           1           1     4059
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699        160296   3.50319e-05       466.255      0.1904      0.1904     4171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799        160298     0.0017578       470.247      0.7616      0.7616     4279
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899        160299    0.00382063       1413.63           1           1     4387
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3936        160299   7.74465e-06       224.168   1.738e-08       0.001     4474  LS failed, Hessian reset
#     3999        160299   1.54543e-05       148.238           1           1     4546
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4014        160300   3.04256e-06       93.6102   2.673e-08       0.001     4611  LS failed, Hessian reset
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
prediction= prophet_model.predict(X_test_copy)
prediction
# Out:
# /Users/diveshkumar/Library/Python/3.8/lib/python/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/diveshkumar/Library/Python/3.8/lib/python/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#                        ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0     2021-01-01 00:15:00  1314.336403   942.779593  1225.440284  1314.336403
# 1     2021-01-01 00:30:00  1314.348027   942.051841  1230.635223  1314.348027
# 2     2021-01-01 00:45:00  1314.359651   938.240332  1225.856134  1314.359651
# 3     2021-01-01 01:00:00  1314.371275   944.011824  1225.583649  1314.371275
# 4     2021-01-01 01:15:00  1314.382899   940.718395  1226.779578  1314.382899
# ...                   ...          ...          ...          ...          ...
# 37243 2022-01-26 23:00:00  1750.595751 -5564.311658  8559.125906 -5174.735894
# 37244 2022-01-26 23:15:00  1750.607375 -5593.314553  8574.612364 -5175.097593
# 37245 2022-01-26 23:30:00  1750.618999 -5600.656554  8597.054459 -5175.459292
# 37246 2022-01-26 23:45:00  1750.630623 -5508.591079  8596.048682 -5175.820991
# 37247 2022-01-27 00:00:00  1750.642247 -5581.454594  8482.207786 -5176.182691
#
#        trend_upper        add1  add1_lower  add1_upper  additive_terms  ...  \
# 0      1314.336403 -120.057760 -120.057760 -120.057760     -224.761456  ...
# 1      1314.348027 -120.057760 -120.057760 -120.057760     -226.720654  ...
# 2      1314.359651 -120.057760 -120.057760 -120.057760     -228.693967  ...
# 3      1314.371275 -120.057760 -120.057760 -120.057760     -230.680119  ...
# 4      1314.382899 -120.057760 -120.057760 -120.057760     -232.675143  ...
# ...            ...         ...         ...         ...             ...  ...
# 37243  8902.841200  -72.754756  -72.754756  -72.754756     -337.409256  ...
# 37244  8903.091378  -72.754756  -72.754756  -72.754756     -339.073315  ...
# 37245  8903.341556  -72.754756  -72.754756  -72.754756     -340.767882  ...
# 37246  8903.591734  -72.754756  -72.754756  -72.754756     -342.487464  ...
# 37247  8903.841912  -72.754756  -72.754756  -72.754756     -344.229593  ...
#
#           weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 0      33.209366     33.209366     33.209366 -135.387762   -135.387762
# 1      33.137644     33.137644     33.137644 -135.431624   -135.431624
# 2      33.068960     33.068960     33.068960 -135.475447   -135.475447
# 3      33.003340     33.003340     33.003340 -135.519233   -135.519233
# 4      32.940807     32.940807     32.940807 -135.562981   -135.562981
# ...          ...           ...           ...         ...           ...
# 37243  35.371197     35.371197     35.371197 -306.453431   -306.453431
# 37244  35.585356     35.585356     35.585356 -306.582838   -306.582838
# 37245  35.794085     35.794085     35.794085 -306.712236   -306.712236
# 37246  35.997265     35.997265     35.997265 -306.841626   -306.841626
# 37247  36.194785     36.194785     36.194785 -306.971008   -306.971008
#
#        yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0       -135.387762                   0.0                         0.0
# 1       -135.431624                   0.0                         0.0
# 2       -135.475447                   0.0                         0.0
# 3       -135.519233                   0.0                         0.0
# 4       -135.562981                   0.0                         0.0
# ...             ...                   ...                         ...
# 37243   -306.453431                   0.0                         0.0
# 37244   -306.582838                   0.0                         0.0
# 37245   -306.712236                   0.0                         0.0
# 37246   -306.841626                   0.0                         0.0
# 37247   -306.971008                   0.0                         0.0
#
#        multiplicative_terms_upper         yhat
# 0                             0.0  1089.574947
# 1                             0.0  1087.627373
# 2                             0.0  1085.665684
# 3                             0.0  1083.691156
# 4                             0.0  1081.707756
# ...                           ...          ...
# 37243                         0.0  1413.186495
# 37244                         0.0  1411.534060
# 37245                         0.0  1409.851117
# 37246                         0.0  1408.143159
# 37247                         0.0  1406.412654
#
# [37248 rows x 28 columns]

# %%
final_df = pd.concat([pd.DataFrame(X_test['y'].to_numpy(), columns = ['Actual Peak Demand']), pd.DataFrame(prediction['yhat'].to_numpy(), columns = ['Predicted Peak Demand'])], axis=1)
final_df
# Out:
#        Actual Peak Demand  Predicted Peak Demand
# 0                   812.8            1089.574947
# 1                   800.0            1087.627373
# 2                   841.6            1085.665684
# 3                   822.4            1083.691156
# 4                   793.6            1081.707756
# ...                   ...                    ...
# 37243              1129.6            1413.186495
# 37244              1155.2            1411.534060
# 37245              1158.4            1409.851117
# 37246              1177.6            1408.143159
# 37247              1161.6            1406.412654
#
# [37248 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error

def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mean_absolute_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred)))

def mse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=True)

def rmse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=False)

# %%
mean_absolute_error_var = mean_absolute_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mean_absolute_percentage_error_var = mean_absolute_percentage_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mse_error_var = mse_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
rmse_error_var = rmse_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])

# %%
print('Test Set Metrics')
print('MAPE: ' , mean_absolute_percentage_error_var)
print('MAE: ', mean_absolute_error_var)
print('MSE: ', mse_error_var)
print('RMSE: ', rmse_error_var)
# Out:
# Test Set Metrics
# MAPE:  inf
# MAE:  312.6933984676104
# MSE:  146673.0430961796
# RMSE:  382.9791679663264

# %%
final_df.plot()
# Out:
# <AxesSubplot:>
