# %% [markdown]
#  # Power Load Prediction for West Zone v02 - Linear Model

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import os
import mysql.connector
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error

# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})
credentials = 'mysql://capstone_user:Capstone22!@capstone-public-db.czwmid1hzf1x.us-west-2.rds.amazonaws.com/mysqldbpublic'

# %%
# %cd ..
# %cd data
path = os.getcwd()
# Out:
# /Volumes/GoogleDrive-106210116385953331360/My Drive/github/w210-capstone-energyloadpredictor
# /Volumes/GoogleDrive-106210116385953331360/My Drive/github/w210-capstone-energyloadpredictor/data

# %%
# read data from csv file
microgrid_01_raw = pd.read_csv("west_interval_data_01-29-2019_01-27-2021.csv")
microgrid_01_raw.head()
# Out:
#   Service Agreement Start Date Time End Date Time  Usage Usage Unit  Cost  \
# 0              west    1/29/19 0:00  1/29/19 0:15  211.2        KWH   NaN
# 1              west    1/29/19 0:15  1/29/19 0:30  210.4        KWH   NaN
# 2              west    1/29/19 0:30  1/29/19 0:45  208.0        KWH   NaN
# 3              west    1/29/19 0:45  1/29/19 1:00  212.0        KWH   NaN
# 4              west    1/29/19 1:00  1/29/19 1:15  203.2        KWH   NaN
#
#    Currency Unit  Avg. Temperature Temperature Unit Event Flags  Peak Demand  \
# 0            NaN              54.0       FAHRENHEIT         NaN        844.8
# 1            NaN              54.0       FAHRENHEIT         NaN        841.6
# 2            NaN              54.0       FAHRENHEIT         NaN        832.0
# 3            NaN              54.0       FAHRENHEIT         NaN        848.0
# 4            NaN              55.0       FAHRENHEIT         NaN        812.8
#
#   Demand Unit
# 0          KW
# 1          KW
# 2          KW
# 3          KW
# 4          KW

# %%
# # print table in database
# mydb = mysql.connector.connect(
#   host="capstone-public-db.czwmid1hzf1x.us-west-2.rds.amazonaws.com",
#   user="capstone_user",
#   password="Capstone22!",
#   database="mysqldbpublic"
# )

# mycursor = mydb.cursor()

# mycursor.execute("SHOW TABLES")

# for x in mycursor:
#   print(x)

# %%
# # write raw data to sql table
# microgrid_01_raw.to_sql('microgrid_01_raw', con=credentials, if_exists='fail')

# %%
def clean_data(data):
  df = data.copy(deep=True)

  # drop columns
  df = df.drop(columns=['Usage Unit', 'Currency Unit', 'Temperature Unit', 'Demand Unit', 'Usage', 'Service Agreement', 'Start Date Time', 'Cost', 'Event Flags'])

  # mapper for column rename
  rename_mapper = {'End Date Time':'end',
                 'Avg. Temperature':'temp',
                 'Peak Demand':'demand'}
  # rename columns
  df = df.rename(mapper=rename_mapper, axis='columns')

  # convert columns to datetime
  df.end = pd.to_datetime(df.end)

  # replace with missing values with previous value
  df.ffill(inplace=True)

  return df

# %%
microgrid_01_clean = clean_data(microgrid_01_raw)

# %%
microgrid_01_clean.head(5)
# Out:
#                   end  temp  demand
# 0 2019-01-29 00:15:00  54.0   844.8
# 1 2019-01-29 00:30:00  54.0   841.6
# 2 2019-01-29 00:45:00  54.0   832.0
# 3 2019-01-29 01:00:00  54.0   848.0
# 4 2019-01-29 01:15:00  55.0   812.8

# %%
# # convert end date time to datetime data type
# power_data_west['End Date Time'] = pd.to_datetime(power_data_west['End Date Time'], infer_datetime_format=True)
# indexedDataset = power_data_west.set_index(['End Date Time'])

# %%
# plot_df_west = pd.DataFrame(power_data_west, columns=['Peak Demand', 'Avg. Temperature', 'End Date Time'])

# %%
plot_df_microgrid_01 = microgrid_01_clean.copy()
microgrid_01_feat = microgrid_01_clean.copy()

# %%
plot_df_microgrid_01
# Out:
#                        end  temp  demand month day_of_week  holiday
# 0      2019-01-29 00:15:00  54.0   844.8   Jan     Tuesday    False
# 1      2019-01-29 00:30:00  54.0   841.6   Jan     Tuesday    False
# 2      2019-01-29 00:45:00  54.0   832.0   Jan     Tuesday    False
# 3      2019-01-29 01:00:00  54.0   848.0   Jan     Tuesday    False
# 4      2019-01-29 01:15:00  55.0   812.8   Jan     Tuesday    False
# ...                    ...   ...     ...   ...         ...      ...
# 104731 2022-01-26 23:00:00  51.0  1129.6   Jan   Wednesday    False
# 104732 2022-01-26 23:15:00  51.0  1155.2   Jan   Wednesday    False
# 104733 2022-01-26 23:30:00  51.0  1158.4   Jan   Wednesday    False
# 104734 2022-01-26 23:45:00  51.0  1177.6   Jan   Wednesday    False
# 104735 2022-01-27 00:00:00  51.0  1161.6   Jan    Thursday    False
#
# [104736 rows x 6 columns]

# %%
plot_df_microgrid_01['end'].min(), plot_df_microgrid_01['end'].max()
# Out:
# (Timestamp('2019-01-29 00:15:00'), Timestamp('2022-01-27 00:00:00'))

# %%
microgrid_01_feat['month'] = microgrid_01_feat['end'].dt.strftime('%b')

# %%
microgrid_01_feat['day_of_week'] = microgrid_01_feat['end'].dt.day_name()

# %%
date_range = pd.date_range(start='2019-01-01', end='2022-01-27')

cal = calendar()
holidays = cal.holidays(start='2019-01-01 00:00:00', end='2022-01-27 00:00:00')

microgrid_01_feat['holiday'] = microgrid_01_feat['end'].dt.date.astype('datetime64').isin(holidays)

# %%
microgrid_01_feat.head(5)
# Out:
#                   end  temp  demand month day_of_week  holiday
# 0 2019-01-29 00:15:00  54.0   844.8   Jan     Tuesday    False
# 1 2019-01-29 00:30:00  54.0   841.6   Jan     Tuesday    False
# 2 2019-01-29 00:45:00  54.0   832.0   Jan     Tuesday    False
# 3 2019-01-29 01:00:00  54.0   848.0   Jan     Tuesday    False
# 4 2019-01-29 01:15:00  55.0   812.8   Jan     Tuesday    False

# %%
microgrid_01_feat.tail(5)
# Out:
#                        end  temp  demand month day_of_week  holiday
# 104731 2022-01-26 23:00:00  51.0  1129.6   Jan   Wednesday    False
# 104732 2022-01-26 23:15:00  51.0  1155.2   Jan   Wednesday    False
# 104733 2022-01-26 23:30:00  51.0  1158.4   Jan   Wednesday    False
# 104734 2022-01-26 23:45:00  51.0  1177.6   Jan   Wednesday    False
# 104735 2022-01-27 00:00:00  51.0  1161.6   Jan    Thursday    False

# %%
microgrid_01_feat.describe()
# Out:
#                 temp         demand
# count  104736.000000  104736.000000
# mean       67.375000    1238.518744
# std        16.590894     302.227591
# min        29.000000       0.000000
# 25%        54.000000    1008.000000
# 50%        66.000000    1232.000000
# 75%        79.000000    1472.000000
# max       114.000000    2124.800000

# %%
microgrid_01_feat.shape
# Out:
# (104736, 6)

# %%
microgrid_01_feat.dtypes
# Out:
# end            datetime64[ns]
# temp                  float64
# demand                float64
# month                  object
# day_of_week            object
# holiday                  bool
# dtype: object

# %%
#For checking missing values in dataset
microgrid_01_feat.isna().sum()
# Out:
# end            0
# temp           0
# demand         0
# month          0
# day_of_week    0
# holiday        0
# dtype: int64

# %%
zero_usage_df = microgrid_01_feat.loc[microgrid_01_feat['demand'] == 0]
zero_usage_df.count()
# Out:
# end            50
# temp           50
# demand         50
# month          50
# day_of_week    50
# holiday        50
# dtype: int64

# %% [markdown]
# dataset.kW.plot()

# %% [markdown]
# ## Linear Timeseries Model

# %%
linear_data = microgrid_01_feat[(microgrid_01_feat['end'] > '2019-01-01') & (microgrid_01_feat['end'] < '2022-02-01')]

# %%
linear_data.head(5)
# Out:
#                   end  temp  demand month day_of_week  holiday
# 0 2019-01-29 00:15:00  54.0   844.8   Jan     Tuesday    False
# 1 2019-01-29 00:30:00  54.0   841.6   Jan     Tuesday    False
# 2 2019-01-29 00:45:00  54.0   832.0   Jan     Tuesday    False
# 3 2019-01-29 01:00:00  54.0   848.0   Jan     Tuesday    False
# 4 2019-01-29 01:15:00  55.0   812.8   Jan     Tuesday    False

# %%
linear_data.tail(5)
# Out:
#                        end  temp  demand month day_of_week  holiday
# 104731 2022-01-26 23:00:00  51.0  1129.6   Jan   Wednesday    False
# 104732 2022-01-26 23:15:00  51.0  1155.2   Jan   Wednesday    False
# 104733 2022-01-26 23:30:00  51.0  1158.4   Jan   Wednesday    False
# 104734 2022-01-26 23:45:00  51.0  1177.6   Jan   Wednesday    False
# 104735 2022-01-27 00:00:00  51.0  1161.6   Jan    Thursday    False

# %%
linear_data_mod = linear_data[['demand', 'temp']].copy()

# %%
linear_data_mod.head(5)
# Out:
#    demand  temp
# 0   844.8  54.0
# 1   841.6  54.0
# 2   832.0  54.0
# 3   848.0  54.0
# 4   812.8  55.0

# %%
linear_data_mod.tail(5)
# Out:
#         demand  temp
# 104731  1129.6  51.0
# 104732  1155.2  51.0
# 104733  1158.4  51.0
# 104734  1177.6  51.0
# 104735  1161.6  51.0

# %%
for i in range(2, 97):
    linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
    linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# Out:
# /Users/samueljohngomez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/samueljohngomez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
linear_data_mod.head(5)
# Out:
#    demand  temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  \
# 0   844.8  54.0           NaN         NaN           NaN         NaN
# 1   841.6  54.0           NaN         NaN           NaN         NaN
# 2   832.0  54.0         844.8        54.0           NaN         NaN
# 3   848.0  54.0         841.6        54.0         844.8        54.0
# 4   812.8  55.0         832.0        54.0         841.6        54.0
#
#    demand_lag_4  temp_lag_4  demand_lag_5  temp_lag_5  ...  demand_lag_92  \
# 0           NaN         NaN           NaN         NaN  ...            NaN
# 1           NaN         NaN           NaN         NaN  ...            NaN
# 2           NaN         NaN           NaN         NaN  ...            NaN
# 3           NaN         NaN           NaN         NaN  ...            NaN
# 4         844.8        54.0           NaN         NaN  ...            NaN
#
#    temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 0          NaN            NaN          NaN            NaN          NaN
# 1          NaN            NaN          NaN            NaN          NaN
# 2          NaN            NaN          NaN            NaN          NaN
# 3          NaN            NaN          NaN            NaN          NaN
# 4          NaN            NaN          NaN            NaN          NaN
#
#    demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 0            NaN          NaN            NaN          NaN
# 1            NaN          NaN            NaN          NaN
# 2            NaN          NaN            NaN          NaN
# 3            NaN          NaN            NaN          NaN
# 4            NaN          NaN            NaN          NaN
#
# [5 rows x 192 columns]

# %%
linear_data_mod.tail(5)
# Out:
#         demand  temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  \
# 104731  1129.6  51.0        1120.0        51.0        1206.4        51.0
# 104732  1155.2  51.0        1187.2        51.0        1120.0        51.0
# 104733  1158.4  51.0        1129.6        51.0        1187.2        51.0
# 104734  1177.6  51.0        1155.2        51.0        1129.6        51.0
# 104735  1161.6  51.0        1158.4        51.0        1155.2        51.0
#
#         demand_lag_4  temp_lag_4  demand_lag_5  temp_lag_5  ...  \
# 104731        1155.2        52.0        1136.0        52.0  ...
# 104732        1206.4        51.0        1155.2        52.0  ...
# 104733        1120.0        51.0        1206.4        51.0  ...
# 104734        1187.2        51.0        1120.0        51.0  ...
# 104735        1129.6        51.0        1187.2        51.0  ...
#
#         demand_lag_92  temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  \
# 104731         1161.6         50.0         1158.4         50.0         1190.4
# 104732         1148.8         50.0         1161.6         50.0         1158.4
# 104733         1190.4         50.0         1148.8         50.0         1161.6
# 104734         1145.6         50.0         1190.4         50.0         1148.8
# 104735         1110.4         50.0         1145.6         50.0         1190.4
#
#         temp_lag_94  demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 104731         50.0         1158.4         50.0         1155.2         49.0
# 104732         50.0         1190.4         50.0         1158.4         50.0
# 104733         50.0         1158.4         50.0         1190.4         50.0
# 104734         50.0         1161.6         50.0         1158.4         50.0
# 104735         50.0         1148.8         50.0         1161.6         50.0
#
# [5 rows x 192 columns]

# %% [markdown]
# ### Split Data

# %%
def timeseries_train_test_split(X, y, test_size):
    
    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))
    
    X_train = X.iloc[:test_index]
    y_train = y.iloc[:test_index]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]
    
    return X_train, X_test, y_train, y_test

# %%
def train_valid_test_split(X, y, train_size, valid_size):
    
    train_index = int(len(X)*train_size)
    valid_index = int(len(X)*valid_size)
    
    X_train = X.iloc[:train_index]
    y_train = y.iloc[:train_index]
    
    X_valid = X.iloc[train_index : train_index + valid_index]
    y_valid = y.iloc[train_index : train_index + valid_index]
    
    X_test = X.iloc[train_index + valid_index : ]
    y_test = y.iloc[train_index + valid_index : ]
    
    return X_train, y_train, X_valid, y_valid, X_test, y_test

# %%
y = linear_data_mod.dropna()['demand']
X = linear_data_mod.dropna().drop(['demand'], axis=1)

# %%
X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

# %%
X_train.head(5)
# Out:
#      temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  demand_lag_4  \
# 96   51.0         876.8        53.0         950.4        53.0         918.4
# 97   51.0         883.2        53.0         876.8        53.0         950.4
# 98   51.0         876.8        51.0         883.2        53.0         876.8
# 99   51.0         889.6        51.0         876.8        51.0         883.2
# 100  50.0         963.2        51.0         889.6        51.0         876.8
#
#      temp_lag_4  demand_lag_5  temp_lag_5  demand_lag_6  ...  demand_lag_92  \
# 96         53.0         921.6        54.0         915.2  ...          812.8
# 97         53.0         918.4        53.0         921.6  ...          822.4
# 98         53.0         950.4        53.0         918.4  ...          822.4
# 99         53.0         876.8        53.0         950.4  ...          835.2
# 100        51.0         883.2        53.0         876.8  ...          870.4
#
#      temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 96          55.0          848.0         54.0          832.0         54.0
# 97          55.0          812.8         55.0          848.0         54.0
# 98          55.0          822.4         55.0          812.8         55.0
# 99          55.0          822.4         55.0          822.4         55.0
# 100         55.0          835.2         55.0          822.4         55.0
#
#      demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 96           841.6         54.0          844.8         54.0
# 97           832.0         54.0          841.6         54.0
# 98           848.0         54.0          832.0         54.0
# 99           812.8         55.0          848.0         54.0
# 100          822.4         55.0          812.8         55.0
#
# [5 rows x 191 columns]

# %%
y_train.head(5)
# Out:
# 96      876.8
# 97      889.6
# 98      963.2
# 99     1011.2
# 100     979.2
# Name: demand, dtype: float64

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(X, y, train_size=0.7, valid_size=0.25 )

# %%
X_train.head()
# Out:
#      temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  demand_lag_4  \
# 96   51.0         876.8        53.0         950.4        53.0         918.4
# 97   51.0         883.2        53.0         876.8        53.0         950.4
# 98   51.0         876.8        51.0         883.2        53.0         876.8
# 99   51.0         889.6        51.0         876.8        51.0         883.2
# 100  50.0         963.2        51.0         889.6        51.0         876.8
#
#      temp_lag_4  demand_lag_5  temp_lag_5  demand_lag_6  ...  demand_lag_92  \
# 96         53.0         921.6        54.0         915.2  ...          812.8
# 97         53.0         918.4        53.0         921.6  ...          822.4
# 98         53.0         950.4        53.0         918.4  ...          822.4
# 99         53.0         876.8        53.0         950.4  ...          835.2
# 100        51.0         883.2        53.0         876.8  ...          870.4
#
#      temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 96          55.0          848.0         54.0          832.0         54.0
# 97          55.0          812.8         55.0          848.0         54.0
# 98          55.0          822.4         55.0          812.8         55.0
# 99          55.0          822.4         55.0          822.4         55.0
# 100         55.0          835.2         55.0          822.4         55.0
#
#      demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 96           841.6         54.0          844.8         54.0
# 97           832.0         54.0          841.6         54.0
# 98           848.0         54.0          832.0         54.0
# 99           812.8         55.0          848.0         54.0
# 100          822.4         55.0          812.8         55.0
#
# [5 rows x 191 columns]

# %%
X_valid.head()
# Out:
#        temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  demand_lag_4  \
# 73344  45.0        1222.4        45.0        1257.6        45.0        1254.4
# 73345  45.0        1232.0        45.0        1222.4        45.0        1257.6
# 73346  45.0        1209.6        45.0        1232.0        45.0        1222.4
# 73347  45.0        1164.8        45.0        1209.6        45.0        1232.0
# 73348  44.0        1152.0        45.0        1164.8        45.0        1209.6
#
#        temp_lag_4  demand_lag_5  temp_lag_5  demand_lag_6  ...  demand_lag_92  \
# 73344        45.0        1251.2        47.0        1222.4  ...         1235.2
# 73345        45.0        1254.4        45.0        1251.2  ...         1232.0
# 73346        45.0        1257.6        45.0        1254.4  ...         1251.2
# 73347        45.0        1222.4        45.0        1257.6  ...         1232.0
# 73348        45.0        1232.0        45.0        1222.4  ...         1193.6
#
#        temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 73344         50.0         1222.4         51.0         1280.0         51.0
# 73345         50.0         1235.2         50.0         1222.4         51.0
# 73346         50.0         1232.0         50.0         1235.2         50.0
# 73347         50.0         1251.2         50.0         1232.0         50.0
# 73348         48.0         1232.0         50.0         1251.2         50.0
#
#        demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 73344         1254.4         51.0         1280.0         51.0
# 73345         1280.0         51.0         1254.4         51.0
# 73346         1222.4         51.0         1280.0         51.0
# 73347         1235.2         50.0         1222.4         51.0
# 73348         1232.0         50.0         1235.2         50.0
#
# [5 rows x 191 columns]

# %%
X_test.head()
# Out:
#        temp  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  demand_lag_4  \
# 99504  80.0        1507.2        78.0        1494.4        78.0        1494.4
# 99505  80.0        1408.0        78.0        1507.2        78.0        1494.4
# 99506  80.0        1366.4        80.0        1408.0        78.0        1507.2
# 99507  80.0        1344.0        80.0        1366.4        80.0        1408.0
# 99508  81.0        1292.8        80.0        1344.0        80.0        1366.4
#
#        temp_lag_4  demand_lag_5  temp_lag_5  demand_lag_6  ...  demand_lag_92  \
# 99504        78.0        1542.4        75.0        1401.6  ...         1398.4
# 99505        78.0        1494.4        78.0        1542.4  ...         1331.2
# 99506        78.0        1494.4        78.0        1494.4  ...         1372.8
# 99507        78.0        1507.2        78.0        1494.4  ...         1369.6
# 99508        80.0        1408.0        78.0        1507.2  ...         1363.2
#
#        temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 99504         61.0         1353.6         57.0         1337.6         57.0
# 99505         61.0         1398.4         61.0         1353.6         57.0
# 99506         61.0         1331.2         61.0         1398.4         61.0
# 99507         61.0         1372.8         61.0         1331.2         61.0
# 99508         64.0         1369.6         61.0         1372.8         61.0
#
#        demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 99504         1356.8         57.0         1372.8         57.0
# 99505         1337.6         57.0         1356.8         57.0
# 99506         1353.6         57.0         1337.6         57.0
# 99507         1398.4         61.0         1353.6         57.0
# 99508         1331.2         61.0         1398.4         61.0
#
# [5 rows x 191 columns]

# %% [markdown]
# ### Model Performance

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mean_absolute_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred)))

def mse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=True)

def rmse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=False)

# %%
def plotModelTrainingResults(model, X_train=X_train, X_valid=X_valid):
  
    prediction = model.predict(X_train)
    
    plt.figure(figsize=(15, 10))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_train.values, label="actual", linewidth=2.0, alpha=0.5)

    mape_error_var = mean_absolute_percentage_error(prediction, y_train)
    mae_error_var = mean_absolute_error(prediction, y_train)
    mse_error_var = mse_error(prediction, y_train)
    rmse_error_var = rmse_error(prediction, y_train)
    
    plt.title("Mean absolute percentage error {0:.2f}%".format(mae_error_var))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
    results = pd.DataFrame({'Actual':y_train, 
                            'Prediction':prediction  
                           })
    
    return results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var
    
train_results, train_mape_error_var, train_mae_error_var, train_mse_error_var, train_rmse_error_var = plotModelTrainingResults(lr)

# %%
train_results.tail()
# Out:
#        Actual   Prediction
# 73339  1251.2  1199.266862
# 73340  1254.4  1209.352242
# 73341  1257.6  1229.322153
# 73342  1222.4  1234.769285
# 73343  1232.0  1236.213346

# %%
print('MAPE: ' , train_mape_error_var)
print('MAE: ', train_mae_error_var)
print('MSE: ', train_mse_error_var)
print('RMSE: ', train_rmse_error_var)
# Out:
# MAPE:  3.1761692615296635
# MAE:  34.389847628753984
# MSE:  2403.3710000220376
# RMSE:  49.024187907828086

# %%
def plotModelPredictions(model, X_train=X_train, X_valid=X_valid):
  
    prediction = model.predict(X_valid)
    
    plt.figure(figsize=(15, 10))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_valid.values, label="actual", linewidth=2.0, alpha=0.5)

    mape_error_var = mean_absolute_percentage_error(prediction, y_valid)
    mae_error_var = mean_absolute_error(prediction, y_valid)
    mse_error_var = mse_error(prediction, y_valid)
    rmse_error_var = rmse_error(prediction, y_valid)
    
    plt.title("Mean absolute percentage error {0:.2f}%".format(mae_error_var))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
    results = pd.DataFrame({'Actual':y_valid, 
                            'Prediction':prediction  
                           })
    
    return results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var
    
results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var = plotModelPredictions(lr)

# %%
results.tail()
# Out:
#        Actual   Prediction
# 99499  1542.4  1417.469257
# 99500  1494.4  1422.557112
# 99501  1494.4  1493.777461
# 99502  1507.2  1486.110878
# 99503  1408.0  1488.704200

# %%
print('MAPE: ' , mape_error_var)
print('MAE: ', mae_error_var)
print('MSE: ', mse_error_var)
print('RMSE: ', rmse_error_var)
# Out:
# MAPE:  3.4373406553660066
# MAE:  39.86349732163999
# MSE:  4472.3519542976655
# RMSE:  66.87564544957802

# %%
def plotCoefficients(model, maxDisplayValues=50):
    
    coefs = pd.DataFrame(model.coef_, X_train.columns)
    coefs.columns = ["coef"]
    coefs["abs"] = coefs.coef.apply(np.abs)
    coefs = coefs.sort_values(by="abs", ascending=False).drop(["abs"], axis=1)
    plot_coefs = coefs.head(maxDisplayValues)
    
    plt.figure(figsize=(15, 7))
    plot_coefs.coef.plot(kind='bar')
    plt.grid(True, axis='y')
    plt.hlines(y=0, xmin=0, xmax=len(plot_coefs), linestyles='dashed');

plotCoefficients(lr)

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))
sns.heatmap(X_train.corr(), linewidths=.5);
# Out:
# /Users/samueljohngomez/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %load_ext sql
# %sql mysql://capstone_user:Capstone22!@capstone-public-db.czwmid1hzf1x.us-west-2.rds.amazonaws.com/mysqldbpublic
# %sql USE mysqldbpublic

# %%
# %sql select * from microgrid_01 \
#         LIMIT 10;
# Out:
#  * mysql://capstone_user:***@capstone-public-db.czwmid1hzf1x.us-west-2.rds.amazonaws.com/mysqldbpublic
# 10 rows affected.
# [('west', datetime.datetime(2019, 1, 29, 0, 0), datetime.datetime(2019, 1, 29, 0, 15), '', 54.0, '', 844.8),
#  ('west', datetime.datetime(2019, 1, 29, 0, 15), datetime.datetime(2019, 1, 29, 0, 30), '', 54.0, '', 841.6),
#  ('west', datetime.datetime(2019, 1, 29, 0, 30), datetime.datetime(2019, 1, 29, 0, 45), '', 54.0, '', 832.0),
#  ('west', datetime.datetime(2019, 1, 29, 0, 45), datetime.datetime(2019, 1, 29, 1, 0), '', 54.0, '', 848.0),
#  ('west', datetime.datetime(2019, 1, 29, 1, 0), datetime.datetime(2019, 1, 29, 1, 15), '', 55.0, '', 812.8),
#  ('west', datetime.datetime(2019, 1, 29, 1, 15), datetime.datetime(2019, 1, 29, 1, 30), '', 55.0, '', 822.4),
#  ('west', datetime.datetime(2019, 1, 29, 1, 30), datetime.datetime(2019, 1, 29, 1, 45), '', 55.0, '', 822.4),
#  ('west', datetime.datetime(2019, 1, 29, 1, 45), datetime.datetime(2019, 1, 29, 2, 0), '', 55.0, '', 835.2),
#  ('west', datetime.datetime(2019, 1, 29, 2, 0), datetime.datetime(2019, 1, 29, 2, 15), '', 55.0, '', 870.4),
#  ('west', datetime.datetime(2019, 1, 29, 2, 15), datetime.datetime(2019, 1, 29, 2, 30), '', 55.0, '', 918.4)]

# %%
last_96 = pd.read_sql('''SELECT end, temp, demand FROM microgrid_01 WHERE YEAR(end)<2022 ORDER BY start DESC LIMIT 1000''', con=credentials)

# %%
last_96
# Out:
#                     end  temp  demand
# 0   2021-12-31 23:45:00  41.0   892.8
# 1   2021-12-31 23:30:00  41.0   870.4
# 2   2021-12-31 23:15:00  41.0   896.0
# 3   2021-12-31 23:00:00  41.0   953.6
# 4   2021-12-31 22:45:00  41.0   931.2
# ..                  ...   ...     ...
# 995 2021-12-21 15:00:00  49.0  1296.0
# 996 2021-12-21 14:45:00  49.0  1241.6
# 997 2021-12-21 14:30:00  49.0  1280.0
# 998 2021-12-21 14:15:00  49.0  1276.8
# 999 2021-12-21 14:00:00  46.0  1254.4
#
# [1000 rows x 3 columns]

# %%
last_96.reindex(index=last_96.index[::-1])
# Out:
#                     end  temp  demand
# 999 2021-12-21 14:00:00  46.0  1254.4
# 998 2021-12-21 14:15:00  49.0  1276.8
# 997 2021-12-21 14:30:00  49.0  1280.0
# 996 2021-12-21 14:45:00  49.0  1241.6
# 995 2021-12-21 15:00:00  49.0  1296.0
# ..                  ...   ...     ...
# 4   2021-12-31 22:45:00  41.0   931.2
# 3   2021-12-31 23:00:00  41.0   953.6
# 2   2021-12-31 23:15:00  41.0   896.0
# 1   2021-12-31 23:30:00  41.0   870.4
# 0   2021-12-31 23:45:00  41.0   892.8
#
# [1000 rows x 3 columns]

# %%
# SELECT id FROM table ORDER BY id ASC LIMIT 4,5
last_96 = pd.read_sql('''SELECT end, temp, demand FROM microgrid_01 WHERE YEAR(end)<2022 ORDER BY start DESC LIMIT 100''', con=credentials)

# %%
last_96
# Out:
#                    end  temp  demand
# 0  2021-12-31 23:45:00  41.0   892.8
# 1  2021-12-31 23:30:00  41.0   870.4
# 2  2021-12-31 23:15:00  41.0   896.0
# 3  2021-12-31 23:00:00  41.0   953.6
# 4  2021-12-31 22:45:00  41.0   931.2
# ..                 ...   ...     ...
# 95 2021-12-31 00:00:00  42.0  1312.0
# 96 2021-12-30 23:45:00  42.0  1318.4
# 97 2021-12-30 23:30:00  42.0  1273.6
# 98 2021-12-30 23:15:00  42.0  1305.6
# 99 2021-12-30 23:00:00  42.0  1302.4
#
# [100 rows x 3 columns]

# %%
linear_data_pred = last_96.copy()

# %%
for i in range(2, 97):
    linear_data_pred["demand_lag_{}".format(i)] = linear_data_pred['demand'].shift(i)
    linear_data_pred["temp_lag_{}".format(i)] = linear_data_pred['temp'].shift(i)
# Out:
# /Users/samueljohngomez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/samueljohngomez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
linear_data_pred
# Out:
#      temp  demand  demand_lag_2  temp_lag_2  demand_lag_3  temp_lag_3  \
# 0    41.0   892.8           NaN         NaN           NaN         NaN
# 1    41.0   870.4           NaN         NaN           NaN         NaN
# 2    41.0   896.0         892.8        41.0           NaN         NaN
# 3    41.0   953.6         870.4        41.0         892.8        41.0
# 4    41.0   931.2         896.0        41.0         870.4        41.0
# ..    ...     ...           ...         ...           ...         ...
# 995  49.0  1296.0        1302.4        52.0        1267.2        52.0
# 996  49.0  1241.6        1280.0        52.0        1302.4        52.0
# 997  49.0  1280.0        1296.0        49.0        1280.0        52.0
# 998  49.0  1276.8        1241.6        49.0        1296.0        49.0
# 999  46.0  1254.4        1280.0        49.0        1241.6        49.0
#
#      demand_lag_4  temp_lag_4  demand_lag_5  temp_lag_5  ...  demand_lag_92  \
# 0             NaN         NaN           NaN         NaN  ...            NaN
# 1             NaN         NaN           NaN         NaN  ...            NaN
# 2             NaN         NaN           NaN         NaN  ...            NaN
# 3             NaN         NaN           NaN         NaN  ...            NaN
# 4           892.8        41.0           NaN         NaN  ...            NaN
# ..            ...         ...           ...         ...  ...            ...
# 995        1257.6        52.0        1251.2        58.0  ...         1472.0
# 996        1267.2        52.0        1257.6        52.0  ...         1462.4
# 997        1302.4        52.0        1267.2        52.0  ...         1436.8
# 998        1280.0        52.0        1302.4        52.0  ...         1417.6
# 999        1296.0        49.0        1280.0        52.0  ...         1388.8
#
#      temp_lag_92  demand_lag_93  temp_lag_93  demand_lag_94  temp_lag_94  \
# 0            NaN            NaN          NaN            NaN          NaN
# 1            NaN            NaN          NaN            NaN          NaN
# 2            NaN            NaN          NaN            NaN          NaN
# 3            NaN            NaN          NaN            NaN          NaN
# 4            NaN            NaN          NaN            NaN          NaN
# ..           ...            ...          ...            ...          ...
# 995         61.0         1507.2         58.0         1500.8         58.0
# 996         61.0         1472.0         61.0         1507.2         58.0
# 997         61.0         1462.4         61.0         1472.0         61.0
# 998         61.0         1436.8         61.0         1462.4         61.0
# 999         59.0         1417.6         61.0         1436.8         61.0
#
#      demand_lag_95  temp_lag_95  demand_lag_96  temp_lag_96
# 0              NaN          NaN            NaN          NaN
# 1              NaN          NaN            NaN          NaN
# 2              NaN          NaN            NaN          NaN
# 3              NaN          NaN            NaN          NaN
# 4              NaN          NaN            NaN          NaN
# ..             ...          ...            ...          ...
# 995         1440.0         58.0         1462.4         58.0
# 996         1500.8         58.0         1440.0         58.0
# 997         1507.2         58.0         1500.8         58.0
# 998         1472.0         61.0         1507.2         58.0
# 999         1462.4         61.0         1472.0         61.0
#
# [1000 rows x 192 columns]

# %%
results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var = plotModelPredictions(lr, X)
# Out:
# LinearRegression()

# %%
X_test.shape
# Out:
# (31392, 191)

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e1243bd22c6> in <module>
# ----> 1 test
#
# NameError: name 'test' is not defined
