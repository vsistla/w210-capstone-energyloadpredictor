# %% [markdown]
#  # Power Load Prediction for West Zone - DNN Model

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
power_data_west = pd.read_csv("west_interval_data_01-29-2019_01-27-2021.csv")

# %%
power_data_west['End Date Time'] = pd.to_datetime(power_data_west['End Date Time'], infer_datetime_format=True)
indexedDataset = power_data_west.set_index(['End Date Time'])

# %%
plot_df_west = pd.DataFrame(power_data_west, columns=['Peak Demand', 'Avg. Temperature', 'End Date Time'])

# %%
plot_df_west['End Date Time'].min()
# Out:
# Timestamp('2019-01-29 00:15:00')

# %%
plot_df_west['End Date Time'].max()
# Out:
# Timestamp('2022-01-27 00:00:00')

# %%
power_data_west['month'] = power_data_west['End Date Time'].dt.strftime('%b')

# %%
power_data_west['day_of_week'] = power_data_west['End Date Time'].dt.day_name()

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

date_range = pd.date_range(start='2019-01-01', end='2022-01-27')

cal = calendar()
holidays = cal.holidays(start=date_range.min(), end=date_range.max())

power_data_west['holiday'] = power_data_west['End Date Time'].dt.date.astype('datetime64').isin(holidays)

# %%
power_data_west.head(10)
# Out:
#   Service Agreement Start Date Time       End Date Time  Usage Usage Unit  \
# 0              west    1/29/19 0:00 2019-01-29 00:15:00  211.2        KWH
# 1              west    1/29/19 0:15 2019-01-29 00:30:00  210.4        KWH
# 2              west    1/29/19 0:30 2019-01-29 00:45:00  208.0        KWH
# 3              west    1/29/19 0:45 2019-01-29 01:00:00  212.0        KWH
# 4              west    1/29/19 1:00 2019-01-29 01:15:00  203.2        KWH
# 5              west    1/29/19 1:15 2019-01-29 01:30:00  205.6        KWH
# 6              west    1/29/19 1:30 2019-01-29 01:45:00  205.6        KWH
# 7              west    1/29/19 1:45 2019-01-29 02:00:00  208.8        KWH
# 8              west    1/29/19 2:00 2019-01-29 02:15:00  217.6        KWH
# 9              west    1/29/19 2:15 2019-01-29 02:30:00  229.6        KWH
#
#    Cost  Currency Unit  Avg. Temperature Temperature Unit Event Flags  \
# 0   NaN            NaN              54.0       FAHRENHEIT         NaN
# 1   NaN            NaN              54.0       FAHRENHEIT         NaN
# 2   NaN            NaN              54.0       FAHRENHEIT         NaN
# 3   NaN            NaN              54.0       FAHRENHEIT         NaN
# 4   NaN            NaN              55.0       FAHRENHEIT         NaN
# 5   NaN            NaN              55.0       FAHRENHEIT         NaN
# 6   NaN            NaN              55.0       FAHRENHEIT         NaN
# 7   NaN            NaN              55.0       FAHRENHEIT         NaN
# 8   NaN            NaN              55.0       FAHRENHEIT         NaN
# 9   NaN            NaN              55.0       FAHRENHEIT         NaN
#
#    Peak Demand Demand Unit month day_of_week  holiday
# 0        844.8          KW   Jan     Tuesday    False
# 1        841.6          KW   Jan     Tuesday    False
# 2        832.0          KW   Jan     Tuesday    False
# 3        848.0          KW   Jan     Tuesday    False
# 4        812.8          KW   Jan     Tuesday    False
# 5        822.4          KW   Jan     Tuesday    False
# 6        822.4          KW   Jan     Tuesday    False
# 7        835.2          KW   Jan     Tuesday    False
# 8        870.4          KW   Jan     Tuesday    False
# 9        918.4          KW   Jan     Tuesday    False

# %%
power_data_west.tail(10)
# Out:
#        Service Agreement Start Date Time       End Date Time  Usage  \
# 104726              west   1/26/22 21:30 2022-01-26 21:45:00  284.0
# 104727              west   1/26/22 21:45 2022-01-26 22:00:00  288.8
# 104728              west   1/26/22 22:00 2022-01-26 22:15:00  301.6
# 104729              west   1/26/22 22:15 2022-01-26 22:30:00  280.0
# 104730              west   1/26/22 22:30 2022-01-26 22:45:00  296.8
# 104731              west   1/26/22 22:45 2022-01-26 23:00:00  282.4
# 104732              west   1/26/22 23:00 2022-01-26 23:15:00  288.8
# 104733              west   1/26/22 23:15 2022-01-26 23:30:00  289.6
# 104734              west   1/26/22 23:30 2022-01-26 23:45:00  294.4
# 104735              west   1/26/22 23:45 2022-01-27 00:00:00  290.4
#
#        Usage Unit  Cost  Currency Unit  Avg. Temperature Temperature Unit  \
# 104726        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104727        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104728        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104729        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104730        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104731        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104732        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104733        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104734        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104735        KWH   NaN            NaN              51.0       FAHRENHEIT
#
#        Event Flags  Peak Demand Demand Unit month day_of_week  holiday
# 104726         NaN       1136.0          KW   Jan   Wednesday    False
# 104727         NaN       1155.2          KW   Jan   Wednesday    False
# 104728         NaN       1206.4          KW   Jan   Wednesday    False
# 104729         NaN       1120.0          KW   Jan   Wednesday    False
# 104730         NaN       1187.2          KW   Jan   Wednesday    False
# 104731         NaN       1129.6          KW   Jan   Wednesday    False
# 104732         NaN       1155.2          KW   Jan   Wednesday    False
# 104733         NaN       1158.4          KW   Jan   Wednesday    False
# 104734         NaN       1177.6          KW   Jan   Wednesday    False
# 104735         NaN       1161.6          KW   Jan    Thursday    False

# %%
power_data_west.describe()
# Out:
#                Usage  Cost  Currency Unit  Avg. Temperature    Peak Demand
# count  104724.000000   0.0            0.0     104716.000000  104724.000000
# mean      309.636443   NaN            NaN         67.377211    1238.545770
# std        75.557612   NaN            NaN         16.591545     302.230457
# min         0.000000   NaN            NaN         29.000000       0.000000
# 25%       252.000000   NaN            NaN         54.000000    1008.000000
# 50%       308.000000   NaN            NaN         66.000000    1232.000000
# 75%       368.000000   NaN            NaN         79.000000    1472.000000
# max       531.200000   NaN            NaN        114.000000    2124.800000

# %%
power_data_west.shape
# Out:
# (104736, 15)

# %%
power_data_west.dtypes
# Out:
# Service Agreement            object
# Start Date Time              object
# End Date Time        datetime64[ns]
# Usage                       float64
# Usage Unit                   object
# Cost                        float64
# Currency Unit               float64
# Avg. Temperature            float64
# Temperature Unit             object
# Event Flags                  object
# Peak Demand                 float64
# Demand Unit                  object
# month                        object
# day_of_week                  object
# holiday                        bool
# dtype: object

# %%
#For checking missing values in dataset
power_data_west.isna().sum()
# Out:
# Service Agreement         0
# Start Date Time           0
# End Date Time             0
# Usage                    12
# Usage Unit               12
# Cost                 104736
# Currency Unit        104736
# Avg. Temperature         20
# Temperature Unit          0
# Event Flags          104730
# Peak Demand              12
# Demand Unit              12
# month                     0
# day_of_week               0
# holiday                   0
# dtype: int64

# %%
power_data_west.fillna(method='ffill',inplace=True)
power_data_west.isna().sum()
# Out:
# Service Agreement         0
# Start Date Time           0
# End Date Time             0
# Usage                     0
# Usage Unit                0
# Cost                 104736
# Currency Unit        104736
# Avg. Temperature          0
# Temperature Unit          0
# Event Flags            3840
# Peak Demand               0
# Demand Unit               0
# month                     0
# day_of_week               0
# holiday                   0
# dtype: int64

# %%
zero_usage_df = power_data_west.loc[power_data_west['Peak Demand'] == 0]
zero_usage_df.count()
# Out:
# Service Agreement    50
# Start Date Time      50
# End Date Time        50
# Usage                50
# Usage Unit           50
# Cost                  0
# Currency Unit         0
# Avg. Temperature     50
# Temperature Unit     50
# Event Flags          50
# Peak Demand          50
# Demand Unit          50
# month                50
# day_of_week          50
# holiday              50
# dtype: int64

# %% [markdown]
# dataset.kW.plot()

# %% [markdown]
# ## GRU Timeseries Model

# %%
dnn_data = power_data_west[(power_data_west['End Date Time'] > '2019-01-01') & (power_data_west['End Date Time'] < '2022-02-01')]

# %%
dnn_data.head(10)
# Out:
#   Service Agreement Start Date Time       End Date Time  Usage Usage Unit  \
# 0              west    1/29/19 0:00 2019-01-29 00:15:00  211.2        KWH
# 1              west    1/29/19 0:15 2019-01-29 00:30:00  210.4        KWH
# 2              west    1/29/19 0:30 2019-01-29 00:45:00  208.0        KWH
# 3              west    1/29/19 0:45 2019-01-29 01:00:00  212.0        KWH
# 4              west    1/29/19 1:00 2019-01-29 01:15:00  203.2        KWH
# 5              west    1/29/19 1:15 2019-01-29 01:30:00  205.6        KWH
# 6              west    1/29/19 1:30 2019-01-29 01:45:00  205.6        KWH
# 7              west    1/29/19 1:45 2019-01-29 02:00:00  208.8        KWH
# 8              west    1/29/19 2:00 2019-01-29 02:15:00  217.6        KWH
# 9              west    1/29/19 2:15 2019-01-29 02:30:00  229.6        KWH
#
#    Cost  Currency Unit  Avg. Temperature Temperature Unit Event Flags  \
# 0   NaN            NaN              54.0       FAHRENHEIT         NaN
# 1   NaN            NaN              54.0       FAHRENHEIT         NaN
# 2   NaN            NaN              54.0       FAHRENHEIT         NaN
# 3   NaN            NaN              54.0       FAHRENHEIT         NaN
# 4   NaN            NaN              55.0       FAHRENHEIT         NaN
# 5   NaN            NaN              55.0       FAHRENHEIT         NaN
# 6   NaN            NaN              55.0       FAHRENHEIT         NaN
# 7   NaN            NaN              55.0       FAHRENHEIT         NaN
# 8   NaN            NaN              55.0       FAHRENHEIT         NaN
# 9   NaN            NaN              55.0       FAHRENHEIT         NaN
#
#    Peak Demand Demand Unit month day_of_week  holiday
# 0        844.8          KW   Jan     Tuesday    False
# 1        841.6          KW   Jan     Tuesday    False
# 2        832.0          KW   Jan     Tuesday    False
# 3        848.0          KW   Jan     Tuesday    False
# 4        812.8          KW   Jan     Tuesday    False
# 5        822.4          KW   Jan     Tuesday    False
# 6        822.4          KW   Jan     Tuesday    False
# 7        835.2          KW   Jan     Tuesday    False
# 8        870.4          KW   Jan     Tuesday    False
# 9        918.4          KW   Jan     Tuesday    False

# %%
dnn_data.tail(10)
# Out:
#        Service Agreement Start Date Time       End Date Time  Usage  \
# 104726              west   1/26/22 21:30 2022-01-26 21:45:00  284.0
# 104727              west   1/26/22 21:45 2022-01-26 22:00:00  288.8
# 104728              west   1/26/22 22:00 2022-01-26 22:15:00  301.6
# 104729              west   1/26/22 22:15 2022-01-26 22:30:00  280.0
# 104730              west   1/26/22 22:30 2022-01-26 22:45:00  296.8
# 104731              west   1/26/22 22:45 2022-01-26 23:00:00  282.4
# 104732              west   1/26/22 23:00 2022-01-26 23:15:00  288.8
# 104733              west   1/26/22 23:15 2022-01-26 23:30:00  289.6
# 104734              west   1/26/22 23:30 2022-01-26 23:45:00  294.4
# 104735              west   1/26/22 23:45 2022-01-27 00:00:00  290.4
#
#        Usage Unit  Cost  Currency Unit  Avg. Temperature Temperature Unit  \
# 104726        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104727        KWH   NaN            NaN              52.0       FAHRENHEIT
# 104728        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104729        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104730        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104731        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104732        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104733        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104734        KWH   NaN            NaN              51.0       FAHRENHEIT
# 104735        KWH   NaN            NaN              51.0       FAHRENHEIT
#
#              Event Flags  Peak Demand Demand Unit month day_of_week  holiday
# 104726  Daylight Savings       1136.0          KW   Jan   Wednesday    False
# 104727  Daylight Savings       1155.2          KW   Jan   Wednesday    False
# 104728  Daylight Savings       1206.4          KW   Jan   Wednesday    False
# 104729  Daylight Savings       1120.0          KW   Jan   Wednesday    False
# 104730  Daylight Savings       1187.2          KW   Jan   Wednesday    False
# 104731  Daylight Savings       1129.6          KW   Jan   Wednesday    False
# 104732  Daylight Savings       1155.2          KW   Jan   Wednesday    False
# 104733  Daylight Savings       1158.4          KW   Jan   Wednesday    False
# 104734  Daylight Savings       1177.6          KW   Jan   Wednesday    False
# 104735  Daylight Savings       1161.6          KW   Jan    Thursday    False

# %%
dnn_data_mod = dnn_data[[ 'month', 'day_of_week' , 'holiday']].copy()

# %%
dnn_data_mod_partial = dnn_data[['Peak Demand', 'Avg. Temperature']].copy()

# %%
dnn_data_mod.tail(1000)
# Out:
#        month day_of_week  holiday  month_N  day_of_week_N  holiday_N
# 103736   Jan      Sunday    False        4              3          0
# 103737   Jan      Sunday    False        4              3          0
# 103738   Jan      Sunday    False        4              3          0
# 103739   Jan      Sunday    False        4              3          0
# 103740   Jan      Sunday    False        4              3          0
# ...      ...         ...      ...      ...            ...        ...
# 104731   Jan   Wednesday    False        4              6          0
# 104732   Jan   Wednesday    False        4              6          0
# 104733   Jan   Wednesday    False        4              6          0
# 104734   Jan   Wednesday    False        4              6          0
# 104735   Jan    Thursday    False        4              4          0
#
# [1000 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# encode Month 
month_encoder = LabelEncoder()

dnn_data_mod['month_N'] = month_encoder.fit_transform(dnn_data_mod['month'])

# %%
# encode day of week

dow_encoder = LabelEncoder()

dnn_data_mod['day_of_week_N'] = dow_encoder.fit_transform(dnn_data_mod['day_of_week'])

# %%
# encode holiday

holiday_encoder = LabelEncoder()

dnn_data_mod['holiday_N'] = holiday_encoder.fit_transform(dnn_data_mod['holiday'])

# %%
dnn_data_mod_partial.head(10)
# Out:
#    Peak Demand  Avg. Temperature
# 0        844.8              54.0
# 1        841.6              54.0
# 2        832.0              54.0
# 3        848.0              54.0
# 4        812.8              55.0
# 5        822.4              55.0
# 6        822.4              55.0
# 7        835.2              55.0
# 8        870.4              55.0
# 9        918.4              55.0

# %%
dnn_data_mod_partial.tail(10)
# Out:
#         Peak Demand  Avg. Temperature
# 104726       1136.0              52.0
# 104727       1155.2              52.0
# 104728       1206.4              51.0
# 104729       1120.0              51.0
# 104730       1187.2              51.0
# 104731       1129.6              51.0
# 104732       1155.2              51.0
# 104733       1158.4              51.0
# 104734       1177.6              51.0
# 104735       1161.6              51.0

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def trasform_to_dnn_format(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset

values = dnn_data_mod_partial.values

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

dnn_format = trasform_to_dnn_format(scaled,  192, 1)
dnn_format = dnn_format.iloc[: , :-1]
dnn_format
# Out:
#         var1(t-192)  var2(t-192)  var1(t-191)  var2(t-191)  var1(t-190)  \
# 192        0.397590     0.294118     0.396084     0.294118     0.391566
# 193        0.396084     0.294118     0.391566     0.294118     0.399096
# 194        0.391566     0.294118     0.399096     0.294118     0.382530
# 195        0.399096     0.294118     0.382530     0.305882     0.387048
# 196        0.382530     0.305882     0.387048     0.305882     0.387048
# ...             ...          ...          ...          ...          ...
# 104731     0.594880     0.223529     0.590361     0.235294     0.584337
# 104732     0.590361     0.235294     0.584337     0.235294     0.578313
# 104733     0.584337     0.235294     0.578313     0.235294     0.569277
# 104734     0.578313     0.235294     0.569277     0.235294     0.560241
# 104735     0.569277     0.235294     0.560241     0.235294     0.593373
#
#         var2(t-190)  var1(t-189)  var2(t-189)  var1(t-188)  var2(t-188)  ...  \
# 192        0.294118     0.399096     0.294118     0.382530     0.305882  ...
# 193        0.294118     0.382530     0.305882     0.387048     0.305882  ...
# 194        0.305882     0.387048     0.305882     0.387048     0.305882  ...
# 195        0.305882     0.387048     0.305882     0.393072     0.305882  ...
# 196        0.305882     0.393072     0.305882     0.409639     0.305882  ...
# ...             ...          ...          ...          ...          ...  ...
# 104731     0.235294     0.578313     0.235294     0.569277     0.235294  ...
# 104732     0.235294     0.569277     0.235294     0.560241     0.235294  ...
# 104733     0.235294     0.560241     0.235294     0.593373     0.235294  ...
# 104734     0.235294     0.593373     0.235294     0.590361     0.235294  ...
# 104735     0.235294     0.590361     0.235294     0.570783     0.235294  ...
#
#         var2(t-5)  var1(t-4)  var2(t-4)  var1(t-3)  var2(t-3)  var1(t-2)  \
# 192      0.341176   0.465361   0.329412   0.457831   0.329412   0.459337
# 193      0.329412   0.457831   0.329412   0.459337   0.329412   0.444277
# 194      0.329412   0.459337   0.329412   0.444277   0.329412   0.456325
# 195      0.329412   0.444277   0.329412   0.456325   0.305882   0.450301
# 196      0.329412   0.456325   0.305882   0.450301   0.305882   0.447289
# ...           ...        ...        ...        ...        ...        ...
# 104731   0.270588   0.543675   0.270588   0.567771   0.258824   0.527108
# 104732   0.270588   0.567771   0.258824   0.527108   0.258824   0.558735
# 104733   0.258824   0.527108   0.258824   0.558735   0.258824   0.531627
# 104734   0.258824   0.558735   0.258824   0.531627   0.258824   0.543675
# 104735   0.258824   0.531627   0.258824   0.543675   0.258824   0.545181
#
#         var2(t-2)  var1(t-1)  var2(t-1)   var1(t)
# 192      0.329412   0.444277   0.329412  0.456325
# 193      0.329412   0.456325   0.305882  0.450301
# 194      0.305882   0.450301   0.305882  0.447289
# 195      0.305882   0.447289   0.305882  0.463855
# 196      0.305882   0.463855   0.305882  0.466867
# ...           ...        ...        ...       ...
# 104731   0.258824   0.558735   0.258824  0.531627
# 104732   0.258824   0.531627   0.258824  0.543675
# 104733   0.258824   0.543675   0.258824  0.545181
# 104734   0.258824   0.545181   0.258824  0.554217
# 104735   0.258824   0.554217   0.258824  0.546687
#
# [104544 rows x 385 columns]

# %%
final_dnn_format = pd.concat([dnn_format, dnn_data_mod['holiday_N'], dnn_data_mod['month_N'] , dnn_data_mod['day_of_week_N']], axis=1, ignore_index=True)
final_dnn_format
# Out:
#           0         1         2         3         4         5         6    \
# 96   0.397590  0.294118  0.396084  0.294118  0.391566  0.294118  0.399096
# 97   0.396084  0.294118  0.391566  0.294118  0.399096  0.294118  0.382530
# 98   0.391566  0.294118  0.399096  0.294118  0.382530  0.305882  0.387048
# 99   0.399096  0.294118  0.382530  0.305882  0.387048  0.305882  0.387048
# 100  0.382530  0.305882  0.387048  0.305882  0.387048  0.305882  0.393072
# ..        ...       ...       ...       ...       ...       ...       ...
# 91        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 92        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 94        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 95        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           7         8         9    ...       187       188       189  \
# 96   0.294118  0.382530  0.305882  ...  0.282353  0.412651  0.282353
# 97   0.305882  0.387048  0.305882  ...  0.282353  0.415663  0.282353
# 98   0.305882  0.387048  0.305882  ...  0.282353  0.412651  0.258824
# 99   0.305882  0.393072  0.305882  ...  0.258824  0.418675  0.258824
# 100  0.305882  0.409639  0.305882  ...  0.258824  0.453313  0.258824
# ..        ...       ...       ...  ...       ...       ...       ...
# 91        NaN       NaN       NaN  ...       NaN       NaN       NaN
# 92        NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93        NaN       NaN       NaN  ...       NaN       NaN       NaN
# 94        NaN       NaN       NaN  ...       NaN       NaN       NaN
# 95        NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#           190       191       192       193  194  195  196
# 96   0.415663  0.282353  0.412651  0.258824    0    4    6
# 97   0.412651  0.258824  0.418675  0.258824    0    4    6
# 98   0.418675  0.258824  0.453313  0.258824    0    4    6
# 99   0.453313  0.258824  0.475904  0.258824    0    4    6
# 100  0.475904  0.258824  0.460843  0.247059    0    4    6
# ..        ...       ...       ...       ...  ...  ...  ...
# 91        NaN       NaN       NaN       NaN    0    4    5
# 92        NaN       NaN       NaN       NaN    0    4    5
# 93        NaN       NaN       NaN       NaN    0    4    5
# 94        NaN       NaN       NaN       NaN    0    4    5
# 95        NaN       NaN       NaN       NaN    0    4    6
#
# [104736 rows x 197 columns]

# %%
# split into train and test sets

values = dnn_format.values
n_train_hours = 2 * 365 * 24 * 4
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
#print(train_X.shape, train_y.shape)

test_X, test_y = test[:, :-1], test[:, -1]
#print(test_X.shape, test_y.shape)


print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (70080, 384) (70080,) (34464, 384) (34464,)

# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from pylab import rcParams
from matplotlib import rc

# design network
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(500, activation='relu', input_shape=(384,)))
model.add(tf.keras.layers.Dense(250, activation='relu'))
model.add(tf.keras.layers.Dense(50, activation='relu'))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='adam', loss='mae')

# fit network
history = model.fit(train_X, train_y, epochs=500, batch_size=50, 
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1402/1402 - 4s - loss: 0.0551 - val_loss: 0.0534 - 4s/epoch - 3ms/step
# Epoch 2/500
# 1402/1402 - 3s - loss: 0.0398 - val_loss: 0.0705 - 3s/epoch - 2ms/step
# Epoch 3/500
# 1402/1402 - 3s - loss: 0.0424 - val_loss: 0.0756 - 3s/epoch - 2ms/step
# Epoch 4/500
# 1402/1402 - 3s - loss: 0.0414 - val_loss: 0.0721 - 3s/epoch - 2ms/step
# Epoch 5/500
# 1402/1402 - 3s - loss: 0.0407 - val_loss: 0.0702 - 3s/epoch - 2ms/step
# Epoch 6/500
# 1402/1402 - 3s - loss: 0.0395 - val_loss: 0.0684 - 3s/epoch - 2ms/step
# Epoch 7/500
# 1402/1402 - 3s - loss: 0.0385 - val_loss: 0.0674 - 3s/epoch - 2ms/step
# Epoch 8/500
# 1402/1402 - 3s - loss: 0.0377 - val_loss: 0.0663 - 3s/epoch - 2ms/step
# Epoch 9/500
# 1402/1402 - 3s - loss: 0.0368 - val_loss: 0.0648 - 3s/epoch - 2ms/step
# Epoch 10/500
# 1402/1402 - 3s - loss: 0.0360 - val_loss: 0.0625 - 3s/epoch - 2ms/step
# Epoch 11/500
# 1402/1402 - 3s - loss: 0.0350 - val_loss: 0.0599 - 3s/epoch - 2ms/step
# Epoch 12/500
# 1402/1402 - 4s - loss: 0.0339 - val_loss: 0.0577 - 4s/epoch - 3ms/step
# Epoch 13/500
# 1402/1402 - 3s - loss: 0.0329 - val_loss: 0.0555 - 3s/epoch - 2ms/step
# Epoch 14/500
# 1402/1402 - 3s - loss: 0.0320 - val_loss: 0.0538 - 3s/epoch - 2ms/step
# Epoch 15/500
# 1402/1402 - 3s - loss: 0.0312 - val_loss: 0.0522 - 3s/epoch - 2ms/step
# Epoch 16/500
# 1402/1402 - 3s - loss: 0.0304 - val_loss: 0.0506 - 3s/epoch - 2ms/step
# Epoch 17/500
# 1402/1402 - 3s - loss: 0.0294 - val_loss: 0.0489 - 3s/epoch - 2ms/step
# Epoch 18/500
# 1402/1402 - 3s - loss: 0.0286 - val_loss: 0.0473 - 3s/epoch - 2ms/step
# Epoch 19/500
# 1402/1402 - 3s - loss: 0.0279 - val_loss: 0.0454 - 3s/epoch - 2ms/step
# Epoch 20/500
# 1402/1402 - 3s - loss: 0.0271 - val_loss: 0.0439 - 3s/epoch - 2ms/step
# Epoch 21/500
# 1402/1402 - 4s - loss: 0.0264 - val_loss: 0.0418 - 4s/epoch - 3ms/step
# Epoch 22/500
# 1402/1402 - 3s - loss: 0.0259 - val_loss: 0.0402 - 3s/epoch - 2ms/step
# Epoch 23/500
# 1402/1402 - 3s - loss: 0.0252 - val_loss: 0.0391 - 3s/epoch - 2ms/step
# Epoch 24/500
# 1402/1402 - 3s - loss: 0.0245 - val_loss: 0.0389 - 3s/epoch - 2ms/step
# Epoch 25/500
# 1402/1402 - 3s - loss: 0.0239 - val_loss: 0.0377 - 3s/epoch - 2ms/step
# Epoch 26/500
# 1402/1402 - 3s - loss: 0.0232 - val_loss: 0.0366 - 3s/epoch - 2ms/step
# Epoch 27/500
# 1402/1402 - 3s - loss: 0.0228 - val_loss: 0.0354 - 3s/epoch - 2ms/step
# Epoch 28/500
# 1402/1402 - 3s - loss: 0.0221 - val_loss: 0.0354 - 3s/epoch - 2ms/step
# Epoch 29/500
# 1402/1402 - 3s - loss: 0.0216 - val_loss: 0.0352 - 3s/epoch - 2ms/step
# Epoch 30/500
# 1402/1402 - 3s - loss: 0.0210 - val_loss: 0.0338 - 3s/epoch - 2ms/step
# Epoch 31/500
# 1402/1402 - 4s - loss: 0.0207 - val_loss: 0.0324 - 4s/epoch - 3ms/step
# Epoch 32/500
# 1402/1402 - 4s - loss: 0.0203 - val_loss: 0.0315 - 4s/epoch - 3ms/step
# Epoch 33/500
# 1402/1402 - 3s - loss: 0.0200 - val_loss: 0.0297 - 3s/epoch - 2ms/step
# Epoch 34/500
# 1402/1402 - 3s - loss: 0.0197 - val_loss: 0.0291 - 3s/epoch - 2ms/step
# Epoch 35/500
# 1402/1402 - 3s - loss: 0.0196 - val_loss: 0.0282 - 3s/epoch - 2ms/step
# Epoch 36/500
# 1402/1402 - 3s - loss: 0.0193 - val_loss: 0.0276 - 3s/epoch - 2ms/step
# Epoch 37/500
# 1402/1402 - 3s - loss: 0.0191 - val_loss: 0.0268 - 3s/epoch - 2ms/step
# Epoch 38/500
# 1402/1402 - 3s - loss: 0.0190 - val_loss: 0.0260 - 3s/epoch - 2ms/step
# Epoch 39/500
# 1402/1402 - 4s - loss: 0.0188 - val_loss: 0.0256 - 4s/epoch - 3ms/step
# Epoch 40/500
# 1402/1402 - 3s - loss: 0.0186 - val_loss: 0.0249 - 3s/epoch - 2ms/step
# Epoch 41/500
# 1402/1402 - 3s - loss: 0.0185 - val_loss: 0.0243 - 3s/epoch - 2ms/step
# Epoch 42/500
# 1402/1402 - 3s - loss: 0.0183 - val_loss: 0.0236 - 3s/epoch - 2ms/step
# Epoch 43/500
# 1402/1402 - 3s - loss: 0.0181 - val_loss: 0.0228 - 3s/epoch - 2ms/step
# Epoch 44/500
# 1402/1402 - 4s - loss: 0.0181 - val_loss: 0.0228 - 4s/epoch - 3ms/step
# Epoch 45/500
# 1402/1402 - 3s - loss: 0.0177 - val_loss: 0.0221 - 3s/epoch - 2ms/step
# Epoch 46/500
# 1402/1402 - 3s - loss: 0.0176 - val_loss: 0.0215 - 3s/epoch - 2ms/step
# Epoch 47/500
# 1402/1402 - 3s - loss: 0.0173 - val_loss: 0.0215 - 3s/epoch - 2ms/step
# Epoch 48/500
# 1402/1402 - 3s - loss: 0.0172 - val_loss: 0.0212 - 3s/epoch - 2ms/step
# Epoch 49/500
# 1402/1402 - 3s - loss: 0.0171 - val_loss: 0.0210 - 3s/epoch - 2ms/step
# Epoch 50/500
# 1402/1402 - 3s - loss: 0.0169 - val_loss: 0.0206 - 3s/epoch - 2ms/step
# Epoch 51/500
# 1402/1402 - 3s - loss: 0.0167 - val_loss: 0.0207 - 3s/epoch - 2ms/step
# Epoch 52/500
# 1402/1402 - 3s - loss: 0.0166 - val_loss: 0.0206 - 3s/epoch - 2ms/step
# Epoch 53/500
# 1402/1402 - 3s - loss: 0.0165 - val_loss: 0.0205 - 3s/epoch - 2ms/step
# Epoch 54/500
# 1402/1402 - 3s - loss: 0.0165 - val_loss: 0.0204 - 3s/epoch - 2ms/step
# Epoch 55/500
# 1402/1402 - 3s - loss: 0.0164 - val_loss: 0.0205 - 3s/epoch - 2ms/step
# Epoch 56/500
# 1402/1402 - 3s - loss: 0.0164 - val_loss: 0.0203 - 3s/epoch - 2ms/step
# Epoch 57/500
# 1402/1402 - 4s - loss: 0.0163 - val_loss: 0.0200 - 4s/epoch - 3ms/step
# Epoch 58/500
# 1402/1402 - 3s - loss: 0.0162 - val_loss: 0.0200 - 3s/epoch - 2ms/step
# Epoch 59/500
# 1402/1402 - 3s - loss: 0.0162 - val_loss: 0.0199 - 3s/epoch - 2ms/step
# Epoch 60/500
# 1402/1402 - 3s - loss: 0.0161 - val_loss: 0.0202 - 3s/epoch - 2ms/step
# Epoch 61/500
# 1402/1402 - 3s - loss: 0.0160 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 62/500
# 1402/1402 - 3s - loss: 0.0160 - val_loss: 0.0199 - 3s/epoch - 2ms/step
# Epoch 63/500
# 1402/1402 - 3s - loss: 0.0159 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 64/500
# 1402/1402 - 3s - loss: 0.0158 - val_loss: 0.0202 - 3s/epoch - 2ms/step
# Epoch 65/500
# 1402/1402 - 3s - loss: 0.0158 - val_loss: 0.0198 - 3s/epoch - 2ms/step
# Epoch 66/500
# 1402/1402 - 3s - loss: 0.0158 - val_loss: 0.0198 - 3s/epoch - 2ms/step
# Epoch 67/500
# 1402/1402 - 3s - loss: 0.0158 - val_loss: 0.0194 - 3s/epoch - 2ms/step
# Epoch 68/500
# 1402/1402 - 3s - loss: 0.0157 - val_loss: 0.0204 - 3s/epoch - 2ms/step
# Epoch 69/500
# 1402/1402 - 3s - loss: 0.0157 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 70/500
# 1402/1402 - 3s - loss: 0.0156 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 71/500
# 1402/1402 - 3s - loss: 0.0156 - val_loss: 0.0197 - 3s/epoch - 2ms/step
# Epoch 72/500
# 1402/1402 - 3s - loss: 0.0156 - val_loss: 0.0197 - 3s/epoch - 2ms/step
# Epoch 73/500
# 1402/1402 - 3s - loss: 0.0155 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 74/500
# 1402/1402 - 3s - loss: 0.0155 - val_loss: 0.0198 - 3s/epoch - 2ms/step
# Epoch 75/500
# 1402/1402 - 3s - loss: 0.0156 - val_loss: 0.0194 - 3s/epoch - 2ms/step
# Epoch 76/500
# 1402/1402 - 3s - loss: 0.0154 - val_loss: 0.0198 - 3s/epoch - 2ms/step
# Epoch 77/500
# 1402/1402 - 4s - loss: 0.0155 - val_loss: 0.0194 - 4s/epoch - 3ms/step
# Epoch 78/500
# 1402/1402 - 3s - loss: 0.0154 - val_loss: 0.0195 - 3s/epoch - 2ms/step
# Epoch 79/500
# 1402/1402 - 3s - loss: 0.0154 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 80/500
# 1402/1402 - 3s - loss: 0.0153 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 81/500
# 1402/1402 - 3s - loss: 0.0154 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 82/500
# 1402/1402 - 3s - loss: 0.0153 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 83/500
# 1402/1402 - 3s - loss: 0.0152 - val_loss: 0.0194 - 3s/epoch - 2ms/step
# Epoch 84/500
# 1402/1402 - 3s - loss: 0.0153 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 85/500
# 1402/1402 - 3s - loss: 0.0152 - val_loss: 0.0195 - 3s/epoch - 2ms/step
# Epoch 86/500
# 1402/1402 - 3s - loss: 0.0152 - val_loss: 0.0189 - 3s/epoch - 2ms/step
# Epoch 87/500
# 1402/1402 - 3s - loss: 0.0151 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 88/500
# 1402/1402 - 3s - loss: 0.0151 - val_loss: 0.0195 - 3s/epoch - 2ms/step
# Epoch 89/500
# 1402/1402 - 3s - loss: 0.0152 - val_loss: 0.0190 - 3s/epoch - 2ms/step
# Epoch 90/500
# 1402/1402 - 3s - loss: 0.0151 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 91/500
# 1402/1402 - 3s - loss: 0.0151 - val_loss: 0.0195 - 3s/epoch - 2ms/step
# Epoch 92/500
# 1402/1402 - 3s - loss: 0.0151 - val_loss: 0.0190 - 3s/epoch - 2ms/step
# Epoch 93/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0195 - 3s/epoch - 2ms/step
# Epoch 94/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0190 - 3s/epoch - 2ms/step
# Epoch 95/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0194 - 3s/epoch - 2ms/step
# Epoch 96/500
# 1402/1402 - 4s - loss: 0.0150 - val_loss: 0.0191 - 4s/epoch - 3ms/step
# Epoch 97/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0196 - 3s/epoch - 2ms/step
# Epoch 98/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 99/500
# 1402/1402 - 3s - loss: 0.0150 - val_loss: 0.0192 - 3s/epoch - 2ms/step
# Epoch 100/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0194 - 3s/epoch - 2ms/step
# Epoch 101/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0192 - 3s/epoch - 2ms/step
# Epoch 102/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 103/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 104/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 105/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0193 - 3s/epoch - 2ms/step
# Epoch 106/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 107/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0189 - 3s/epoch - 2ms/step
# Epoch 108/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0190 - 3s/epoch - 2ms/step
# Epoch 109/500
# 1402/1402 - 3s - loss: 0.0149 - val_loss: 0.0192 - 3s/epoch - 2ms/step
# Epoch 110/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 111/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 112/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0188 - 3s/epoch - 2ms/step
# Epoch 113/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0189 - 3s/epoch - 2ms/step
# Epoch 114/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 115/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0189 - 3s/epoch - 2ms/step
# Epoch 116/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0188 - 3s/epoch - 2ms/step
# Epoch 117/500
# 1402/1402 - 3s - loss: 0.0148 - val_loss: 0.0188 - 3s/epoch - 2ms/step
# Epoch 118/500
# 1402/1402 - 4s - loss: 0.0147 - val_loss: 0.0186 - 4s/epoch - 3ms/step
# Epoch 119/500
# 1402/1402 - 4s - loss: 0.0147 - val_loss: 0.0189 - 4s/epoch - 3ms/step
# Epoch 120/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 121/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0189 - 3s/epoch - 2ms/step
# Epoch 122/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 123/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 124/500
# 1402/1402 - 4s - loss: 0.0147 - val_loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 125/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0188 - 3s/epoch - 2ms/step
# Epoch 126/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 127/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 128/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 129/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 130/500
# 1402/1402 - 5s - loss: 0.0146 - val_loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 131/500
# 1402/1402 - 4s - loss: 0.0146 - val_loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 132/500
# 1402/1402 - 4s - loss: 0.0146 - val_loss: 0.0186 - 4s/epoch - 3ms/step
# Epoch 133/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 134/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 135/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0191 - 3s/epoch - 2ms/step
# Epoch 136/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 137/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0183 - 3s/epoch - 2ms/step
# Epoch 138/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 139/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 140/500
# 1402/1402 - 3s - loss: 0.0147 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 141/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 142/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 143/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 144/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 145/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0183 - 3s/epoch - 2ms/step
# Epoch 146/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0187 - 3s/epoch - 2ms/step
# Epoch 147/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0183 - 3s/epoch - 2ms/step
# Epoch 148/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 149/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0183 - 3s/epoch - 2ms/step
# Epoch 150/500
# 1402/1402 - 3s - loss: 0.0146 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 151/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 152/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0186 - 3s/epoch - 2ms/step
# Epoch 153/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 154/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 155/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 156/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 157/500
# 1402/1402 - 3s - loss: 0.0145 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 158/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 159/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0183 - 3s/epoch - 2ms/step
# Epoch 160/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0185 - 3s/epoch - 2ms/step
# Epoch 161/500
# 1402/1402 - 4s - loss: 0.0144 - val_loss: 0.0180 - 4s/epoch - 3ms/step
# Epoch 162/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 163/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 164/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 165/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 166/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 167/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 168/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 169/500
# 1402/1402 - 4s - loss: 0.0143 - val_loss: 0.0180 - 4s/epoch - 3ms/step
# Epoch 170/500
# 1402/1402 - 4s - loss: 0.0144 - val_loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 171/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 172/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0184 - 3s/epoch - 2ms/step
# Epoch 173/500
# 1402/1402 - 4s - loss: 0.0143 - val_loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 174/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 175/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 176/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 177/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 178/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 179/500
# 1402/1402 - 3s - loss: 0.0144 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 180/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 181/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 182/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 183/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 184/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 185/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 186/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 187/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 188/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 189/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 190/500
# 1402/1402 - 4s - loss: 0.0143 - val_loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 191/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 192/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 193/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 194/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 195/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 196/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 197/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 198/500
# 1402/1402 - 4s - loss: 0.0142 - val_loss: 0.0177 - 4s/epoch - 3ms/step
# Epoch 199/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 200/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 201/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 202/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 203/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 204/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 205/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 206/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 207/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 208/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0181 - 3s/epoch - 2ms/step
# Epoch 209/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 210/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 211/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 212/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 213/500
# 1402/1402 - 3s - loss: 0.0143 - val_loss: 0.0182 - 3s/epoch - 2ms/step
# Epoch 214/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 215/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0180 - 3s/epoch - 2ms/step
# Epoch 216/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 217/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 218/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 219/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 220/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 221/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 222/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 223/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 224/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 225/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 226/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 227/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 228/500
# 1402/1402 - 4s - loss: 0.0142 - val_loss: 0.0175 - 4s/epoch - 3ms/step
# Epoch 229/500
# 1402/1402 - 4s - loss: 0.0141 - val_loss: 0.0174 - 4s/epoch - 3ms/step
# Epoch 230/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 231/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 232/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 233/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 234/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 235/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 236/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 237/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 238/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 239/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 240/500
# 1402/1402 - 3s - loss: 0.0142 - val_loss: 0.0179 - 3s/epoch - 2ms/step
# Epoch 241/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 242/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 243/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 244/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 245/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 246/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 247/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 248/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 249/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 250/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 251/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 252/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0177 - 3s/epoch - 2ms/step
# Epoch 253/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 254/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 255/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 256/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 257/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 258/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 259/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 260/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 261/500
# 1402/1402 - 4s - loss: 0.0140 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 262/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 263/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 264/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 265/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 266/500
# 1402/1402 - 4s - loss: 0.0140 - val_loss: 0.0173 - 4s/epoch - 3ms/step
# Epoch 267/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 268/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 269/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 270/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 271/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 272/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 273/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 274/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 275/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 276/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 277/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 278/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 279/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 280/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 281/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 282/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 283/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 284/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0178 - 3s/epoch - 2ms/step
# Epoch 285/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0176 - 3s/epoch - 2ms/step
# Epoch 286/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 287/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 288/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 289/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 290/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 291/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 292/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 293/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 294/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 295/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 296/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 297/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 298/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 299/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 300/500
# 1402/1402 - 4s - loss: 0.0140 - val_loss: 0.0176 - 4s/epoch - 3ms/step
# Epoch 301/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 302/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 303/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 304/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 305/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 306/500
# 1402/1402 - 4s - loss: 0.0140 - val_loss: 0.0175 - 4s/epoch - 3ms/step
# Epoch 307/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 308/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 309/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 310/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 311/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 312/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 313/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 314/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 315/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 316/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 317/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 318/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 319/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 320/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 321/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 322/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 323/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 324/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 325/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 326/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 327/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 328/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 329/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 330/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 331/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 332/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 333/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 334/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 335/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 336/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 337/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 338/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 339/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 340/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0175 - 3s/epoch - 2ms/step
# Epoch 341/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 342/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 343/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 344/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 345/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 346/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 347/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 348/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 349/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 350/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 351/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 352/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 353/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 354/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 355/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 356/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 357/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 358/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 359/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 360/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 361/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 362/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 363/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 364/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 365/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 366/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 367/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 368/500
# 1402/1402 - 5s - loss: 0.0139 - val_loss: 0.0173 - 5s/epoch - 3ms/step
# Epoch 369/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 370/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 371/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 372/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 373/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 374/500
# 1402/1402 - 3018s - loss: 0.0139 - val_loss: 0.0170 - 3018s/epoch - 2s/step
# Epoch 375/500
# 1402/1402 - 11s - loss: 0.0138 - val_loss: 0.0171 - 11s/epoch - 8ms/step
# Epoch 376/500
# 1402/1402 - 10s - loss: 0.0139 - val_loss: 0.0173 - 10s/epoch - 7ms/step
# Epoch 377/500
# 1402/1402 - 5s - loss: 0.0139 - val_loss: 0.0171 - 5s/epoch - 3ms/step
# Epoch 378/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0171 - 4s/epoch - 3ms/step
# Epoch 379/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0170 - 4s/epoch - 3ms/step
# Epoch 380/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 381/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 382/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 383/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 384/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 385/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0171 - 4s/epoch - 3ms/step
# Epoch 386/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 387/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 388/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 389/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 390/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 391/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 392/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 393/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 394/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 395/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 396/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0173 - 3s/epoch - 2ms/step
# Epoch 397/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 398/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 399/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 400/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 401/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 402/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 403/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 404/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 405/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 406/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 407/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 408/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 409/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 410/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 411/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 412/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 413/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 414/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 415/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0169 - 4s/epoch - 3ms/step
# Epoch 416/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 417/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 418/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 419/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 420/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 421/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 422/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 423/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 424/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 425/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 426/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 427/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 428/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0174 - 3s/epoch - 2ms/step
# Epoch 429/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 430/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 431/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 432/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 433/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 434/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 435/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 436/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 437/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 438/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 439/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 440/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 441/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 442/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 443/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 444/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 445/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 446/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0167 - 3s/epoch - 2ms/step
# Epoch 447/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 448/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0169 - 4s/epoch - 3ms/step
# Epoch 449/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 450/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0168 - 4s/epoch - 3ms/step
# Epoch 451/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 452/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 453/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 454/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 455/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 456/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 457/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 458/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0168 - 4s/epoch - 3ms/step
# Epoch 459/500
# 1402/1402 - 4s - loss: 0.0138 - val_loss: 0.0169 - 4s/epoch - 3ms/step
# Epoch 460/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 461/500
# 1402/1402 - 4s - loss: 0.0140 - val_loss: 0.0172 - 4s/epoch - 3ms/step
# Epoch 462/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 463/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 464/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 465/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 466/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 467/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 468/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 469/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 470/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 471/500
# 1402/1402 - 3s - loss: 0.0140 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 472/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 473/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 474/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 475/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 476/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0172 - 3s/epoch - 2ms/step
# Epoch 477/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 478/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0167 - 3s/epoch - 2ms/step
# Epoch 479/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 480/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 481/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 482/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 483/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 484/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 485/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 486/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0167 - 3s/epoch - 2ms/step
# Epoch 487/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0168 - 3s/epoch - 2ms/step
# Epoch 488/500
# 1402/1402 - 3s - loss: 0.0137 - val_loss: 0.0167 - 3s/epoch - 2ms/step
# Epoch 489/500
# 1402/1402 - 3s - loss: 0.0137 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 490/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0171 - 4s/epoch - 3ms/step
# Epoch 491/500
# 1402/1402 - 3s - loss: 0.0141 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 492/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 493/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 494/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 495/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 496/500
# 1402/1402 - 4s - loss: 0.0139 - val_loss: 0.0170 - 4s/epoch - 2ms/step
# Epoch 497/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0170 - 3s/epoch - 2ms/step
# Epoch 498/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0169 - 3s/epoch - 2ms/step
# Epoch 499/500
# 1402/1402 - 3s - loss: 0.0138 - val_loss: 0.0171 - 3s/epoch - 2ms/step
# Epoch 500/500
# 1402/1402 - 3s - loss: 0.0139 - val_loss: 0.0170 - 3s/epoch - 2ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
model.save('./dnn_model_v1')
# Out:
# INFO:tensorflow:Assets written to: ./dnn_model_v1/assets

# %%
# make a prediction
print('Running Prediction')
y_pred = model.predict(test_X)
print('Done')
# Out:
# Running Prediction
# Done

# %%
y_pred.shape
# Out:
# (34464, 1)

# %%
from numpy import concatenate
# invert scaling for forecast
inv_y_pred = concatenate((y_pred, test_X[:, -1:]), axis=1)
inv_y_pred=  scaler.inverse_transform(inv_y_pred)
inv_y_pred = inv_y_pred[:,0]
inv_y_pred
# Out:
# array([1228.03094788, 1174.02902222, 1196.20609131, ..., 1152.74836731,
#        1152.02824707, 1163.42757568])

# %%
y_pred.shape
# Out:
# (34464, 1)

# %%
test_y.shape
# Out:
# (34464,)

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
inv_y_pred.shape
# Out:
# (34464,)

# %%
inv_y_pred
# Out:
# array([1228.03094788, 1174.02902222, 1196.20609131, ..., 1152.74836731,
#        1152.02824707, 1163.42757568])

# %%
inv_y.shape
# Out:
# (34464,)

# %%
inv_y
# Out:
# array([1152. , 1200. , 1174.4, ..., 1158.4, 1177.6, 1161.6])

# %%
# invert scaling for actual
train_X = train_X.reshape((train_X.shape[0], 96*2))

train_y = train_y.reshape((len(train_y), 1))
inv_train_y = concatenate((train_y, train_X[:, -1:]), axis=1)
inv_train_y = scaler.inverse_transform(inv_train_y)
inv_train_y = inv_train_y[:,0]
inv_train_y.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [162], in <module>
#       1 # invert scaling for actual
# ----> 2 train_X = train_X.reshape((train_X.shape[0], 96*2))
#       4 train_y = train_y.reshape((len(train_y), 1))
#       5 inv_train_y = concatenate((train_y, train_X[:, -1:]), axis=1)
#
# ValueError: cannot reshape array of size 26910720 into shape (70080,192)

# %%
final_df = pd.concat([pd.DataFrame(inv_y, columns = ['Actual Peak Demand']), pd.DataFrame(inv_y_pred, columns = ['Predicted Peak Demand'])], axis=1)
final_df
# Out:
#        Actual Peak Demand  Predicted Peak Demand
# 0                  1152.0            1228.030948
# 1                  1200.0            1174.029022
# 2                  1174.4            1196.206091
# 3                  1152.0            1184.148193
# 4                  1264.0            1170.874348
# ...                   ...                    ...
# 34459              1129.6            1175.066269
# 34460              1155.2            1138.850655
# 34461              1158.4            1152.748367
# 34462              1177.6            1152.028247
# 34463              1161.6            1163.427576
#
# [34464 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error



def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mean_absolute_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred)))

def mse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=True)

def rmse_error(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=False)

# %%
mean_absolute_error_var = mean_absolute_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mean_absolute_percentage_error_var = mean_absolute_percentage_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mse_error_var = mse_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
rmse_error_var = rmse_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])

# %%
print('Test Set Metrics')
print('MAPE: ' , mean_absolute_percentage_error_var)
print('MAE: ', mean_absolute_error_var)
print('MSE: ', mse_error_var)
print('RMSE: ', rmse_error_var)
# Out:
# Test Set Metrics
# MAPE:  inf
# MAE:  36.07325493646755
# MSE:  2870.319714704922
# RMSE:  53.57536481168301

# %%
final_df.plot()
# Out:
# <AxesSubplot:>

# %%
final_df.head(96).plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(np.arange(0, len(inv_train_y)), inv_train_y, 'g', label="history")
plt.plot(np.arange(len(inv_train_y),  len(inv_train_y) + len(inv_y)), inv_y, marker='.', label="true")
plt.plot(np.arange(len(inv_train_y),  len(inv_train_y) + len(inv_y)), inv_y_pred, 'r', label="prediction")
plt.ylabel('Peak Load')
plt.xlabel('Time Step')
plt.legend()
plt.show();
