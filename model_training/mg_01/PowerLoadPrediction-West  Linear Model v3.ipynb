# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
import pandas as pd
# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
#power_data_west = pd.read_csv("west_interval_data_01-29-2019_01-27-2021.csv")
power_data_west = pd.read_csv("westdata_augmented.csv")
# Out:
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/1789067132.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   power_data_west = pd.read_csv("westdata_augmented.csv")

# %%
power_data_west.head(10)
# Out:
#    Unnamed: 0  index_x service                start                  end  \
# 0           0        0    west  2019-01-29 00:00:00  2019-01-29 00:15:00
# 1           1        1    west  2019-01-29 00:15:00  2019-01-29 00:30:00
# 2           2        2    west  2019-01-29 00:30:00  2019-01-29 00:45:00
# 3           3        3    west  2019-01-29 00:45:00  2019-01-29 01:00:00
# 4           4        4    west  2019-01-29 01:00:00  2019-01-29 01:15:00
# 5           5        5    west  2019-01-29 01:15:00  2019-01-29 01:30:00
# 6           6        6    west  2019-01-29 01:30:00  2019-01-29 01:45:00
# 7           7        7    west  2019-01-29 01:45:00  2019-01-29 02:00:00
# 8           8        8    west  2019-01-29 02:00:00  2019-01-29 02:15:00
# 9           9        9    west  2019-01-29 02:15:00  2019-01-29 02:30:00
#
#    usage  cost  temp event_flag  demand            sfm  index_y          dt  \
# 0  211.2   NaN  54.0        NaN   844.8  2019-01-29 00      680  1548748800
# 1  210.4   NaN  54.0        NaN   841.6  2019-01-29 00      680  1548748800
# 2  208.0   NaN  54.0        NaN   832.0  2019-01-29 00      680  1548748800
# 3  212.0   NaN  54.0        NaN   848.0  2019-01-29 00      680  1548748800
# 4  203.2   NaN  55.0        NaN   812.8  2019-01-29 01      681  1548752400
# 5  205.6   NaN  55.0        NaN   822.4  2019-01-29 01      681  1548752400
# 6  205.6   NaN  55.0        NaN   822.4  2019-01-29 01      681  1548752400
# 7  208.8   NaN  55.0        NaN   835.2  2019-01-29 01      681  1548752400
# 8  217.6   NaN  55.0        NaN   870.4  2019-01-29 02      682  1548756000
# 9  229.6   NaN  55.0        NaN   918.4  2019-01-29 02      682  1548756000
#
#           dt_iso  humidity  humidity_temp        pt_date
# 0  2019-01-29 08        21          63.86  2019-01-29 00
# 1  2019-01-29 08        21          63.86  2019-01-29 00
# 2  2019-01-29 08        21          63.86  2019-01-29 00
# 3  2019-01-29 08        21          63.86  2019-01-29 00
# 4  2019-01-29 09        21          63.41  2019-01-29 01
# 5  2019-01-29 09        21          63.41  2019-01-29 01
# 6  2019-01-29 09        21          63.41  2019-01-29 01
# 7  2019-01-29 09        21          63.41  2019-01-29 01
# 8  2019-01-29 10        22          62.98  2019-01-29 02
# 9  2019-01-29 10        22          62.98  2019-01-29 02

# %%
power_data_west['end'] = pd.to_datetime(power_data_west['end'], infer_datetime_format=True)
indexedDataset = power_data_west.set_index(['end'])

# %%
plot_df_west = pd.DataFrame(power_data_west, columns=['demand', 'temp', 'end', 'humidity'])

# %%
plot_df_west['end'].min()
# Out:
# Timestamp('2019-01-29 00:15:00')

# %%
plot_df_west['end'].max()
# Out:
# Timestamp('2022-01-25 16:00:00')

# %%
power_data_west['month'] = power_data_west['end'].dt.strftime('%b')

# %%
from calendar import month_abbr

lower_ma = [m.lower() for m in month_abbr]

# one-liner with Pandas
power_data_west['month_int'] = power_data_west['month'].str.lower().map(lambda m: lower_ma.index(m)).astype('Int8')

# %%
power_data_west['day_of_week'] = power_data_west['end'].dt.day_name()

# %%
power_data_west['day_of_week_int'] = power_data_west['end'].dt.day_of_week

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

date_range = pd.date_range(start='2019-01-01', end='2022-01-27')

cal = calendar()
holidays = cal.holidays(start=date_range.min(), end=date_range.max())

power_data_west['holiday'] = power_data_west['end'].dt.date.astype('datetime64').isin(holidays)

# %%
power_data_west.head(10)
# Out:
#    Unnamed: 0  index_x service                start                 end  \
# 0           0        0    west  2019-01-29 00:00:00 2019-01-29 00:15:00
# 1           1        1    west  2019-01-29 00:15:00 2019-01-29 00:30:00
# 2           2        2    west  2019-01-29 00:30:00 2019-01-29 00:45:00
# 3           3        3    west  2019-01-29 00:45:00 2019-01-29 01:00:00
# 4           4        4    west  2019-01-29 01:00:00 2019-01-29 01:15:00
# 5           5        5    west  2019-01-29 01:15:00 2019-01-29 01:30:00
# 6           6        6    west  2019-01-29 01:30:00 2019-01-29 01:45:00
# 7           7        7    west  2019-01-29 01:45:00 2019-01-29 02:00:00
# 8           8        8    west  2019-01-29 02:00:00 2019-01-29 02:15:00
# 9           9        9    west  2019-01-29 02:15:00 2019-01-29 02:30:00
#
#    usage  cost  temp event_flag  demand  ...          dt         dt_iso  \
# 0  211.2   NaN  54.0        NaN   844.8  ...  1548748800  2019-01-29 08
# 1  210.4   NaN  54.0        NaN   841.6  ...  1548748800  2019-01-29 08
# 2  208.0   NaN  54.0        NaN   832.0  ...  1548748800  2019-01-29 08
# 3  212.0   NaN  54.0        NaN   848.0  ...  1548748800  2019-01-29 08
# 4  203.2   NaN  55.0        NaN   812.8  ...  1548752400  2019-01-29 09
# 5  205.6   NaN  55.0        NaN   822.4  ...  1548752400  2019-01-29 09
# 6  205.6   NaN  55.0        NaN   822.4  ...  1548752400  2019-01-29 09
# 7  208.8   NaN  55.0        NaN   835.2  ...  1548752400  2019-01-29 09
# 8  217.6   NaN  55.0        NaN   870.4  ...  1548756000  2019-01-29 10
# 9  229.6   NaN  55.0        NaN   918.4  ...  1548756000  2019-01-29 10
#
#    humidity humidity_temp        pt_date  month month_int day_of_week  \
# 0        21         63.86  2019-01-29 00    Jan         1     Tuesday
# 1        21         63.86  2019-01-29 00    Jan         1     Tuesday
# 2        21         63.86  2019-01-29 00    Jan         1     Tuesday
# 3        21         63.86  2019-01-29 00    Jan         1     Tuesday
# 4        21         63.41  2019-01-29 01    Jan         1     Tuesday
# 5        21         63.41  2019-01-29 01    Jan         1     Tuesday
# 6        21         63.41  2019-01-29 01    Jan         1     Tuesday
# 7        21         63.41  2019-01-29 01    Jan         1     Tuesday
# 8        22         62.98  2019-01-29 02    Jan         1     Tuesday
# 9        22         62.98  2019-01-29 02    Jan         1     Tuesday
#
#    day_of_week_int holiday
# 0                1   False
# 1                1   False
# 2                1   False
# 3                1   False
# 4                1   False
# 5                1   False
# 6                1   False
# 7                1   False
# 8                1   False
# 9                1   False
#
# [10 rows x 22 columns]

# %%
power_data_west.tail(10)
# Out:
#         Unnamed: 0  index_x service                start                 end  \
# 104598      104598   104598    west  2022-01-25 13:30:00 2022-01-25 13:45:00
# 104599      104599   104599    west  2022-01-25 13:45:00 2022-01-25 14:00:00
# 104600      104600   104600    west  2022-01-25 14:00:00 2022-01-25 14:15:00
# 104601      104601   104601    west  2022-01-25 14:15:00 2022-01-25 14:30:00
# 104602      104602   104602    west  2022-01-25 14:30:00 2022-01-25 14:45:00
# 104603      104603   104603    west  2022-01-25 14:45:00 2022-01-25 15:00:00
# 104604      104604   104604    west  2022-01-25 15:00:00 2022-01-25 15:15:00
# 104605      104605   104605    west  2022-01-25 15:15:00 2022-01-25 15:30:00
# 104606      104606   104606    west  2022-01-25 15:30:00 2022-01-25 15:45:00
# 104607      104607   104607    west  2022-01-25 15:45:00 2022-01-25 16:00:00
#
#         usage  cost  temp event_flag  demand  ...          dt         dt_iso  \
# 104598  301.6   NaN  66.0        NaN  1206.4  ...  1643144400  2022-01-25 21
# 104599  300.0   NaN  66.0        NaN  1200.0  ...  1643144400  2022-01-25 21
# 104600  300.8   NaN  67.0        NaN  1203.2  ...  1643148000  2022-01-25 22
# 104601  309.6   NaN  67.0        NaN  1238.4  ...  1643148000  2022-01-25 22
# 104602  297.6   NaN  67.0        NaN  1190.4  ...  1643148000  2022-01-25 22
# 104603  297.6   NaN  67.0        NaN  1190.4  ...  1643148000  2022-01-25 22
# 104604  295.2   NaN  67.0        NaN  1180.8  ...  1643151600  2022-01-25 23
# 104605  304.8   NaN  67.0        NaN  1219.2  ...  1643151600  2022-01-25 23
# 104606  309.6   NaN  67.0        NaN  1238.4  ...  1643151600  2022-01-25 23
# 104607  296.8   NaN  67.0        NaN  1187.2  ...  1643151600  2022-01-25 23
#
#         humidity humidity_temp        pt_date  month month_int day_of_week  \
# 104598        37         68.23  2022-01-25 13    Jan         1     Tuesday
# 104599        37         68.23  2022-01-25 13    Jan         1     Tuesday
# 104600        27         69.22  2022-01-25 14    Jan         1     Tuesday
# 104601        27         69.22  2022-01-25 14    Jan         1     Tuesday
# 104602        27         69.22  2022-01-25 14    Jan         1     Tuesday
# 104603        27         69.22  2022-01-25 14    Jan         1     Tuesday
# 104604        26         68.34  2022-01-25 15    Jan         1     Tuesday
# 104605        26         68.34  2022-01-25 15    Jan         1     Tuesday
# 104606        26         68.34  2022-01-25 15    Jan         1     Tuesday
# 104607        26         68.34  2022-01-25 15    Jan         1     Tuesday
#
#         day_of_week_int holiday
# 104598                1   False
# 104599                1   False
# 104600                1   False
# 104601                1   False
# 104602                1   False
# 104603                1   False
# 104604                1   False
# 104605                1   False
# 104606                1   False
# 104607                1   False
#
# [10 rows x 22 columns]

# %%
power_data_west.describe()
# Out:
#           Unnamed: 0        index_x          usage  cost          temp  \
# count  104608.000000  104608.000000  104596.000000   0.0  104588.00000
# mean    52303.500000   52303.500000     309.658615   NaN      67.39232
# std     30197.872817   30197.872817      75.599852   NaN      16.59371
# min         0.000000       0.000000       0.000000   NaN      29.00000
# 25%     26151.750000   26151.750000     252.000000   NaN      54.00000
# 50%     52303.500000   52303.500000     308.000000   NaN      66.00000
# 75%     78455.250000   78455.250000     368.000000   NaN      79.00000
# max    104607.000000  104607.000000     531.200000   NaN     114.00000
#
#               demand        index_y            dt       humidity  \
# count  104596.000000  104608.000000  1.046080e+05  104608.000000
# mean     1238.634456   13764.530284  1.595853e+09      52.635401
# std       302.399419    7560.847033  2.721905e+07      22.815913
# min         0.000000     680.000000  1.548749e+09       3.000000
# 25%      1008.000000    7217.750000  1.572285e+09      34.000000
# 50%      1232.000000   13755.500000  1.595821e+09      49.000000
# 75%      1472.000000   20317.250000  1.619443e+09      70.000000
# max      2124.800000   26903.000000  1.643152e+09     100.000000
#
#        humidity_temp     month_int  day_of_week_int
# count  104608.000000  104608.00000    104608.000000
# mean       68.527903       6.54298         2.998748
# std        15.741494       3.43464         2.002753
# min        32.200000       1.00000         0.000000
# 25%        55.850000       4.00000         1.000000
# 50%        66.900000       7.00000         3.000000
# 75%        80.550000      10.00000         5.000000
# max       110.680000      12.00000         6.000000

# %%
power_data_west.shape
# Out:
# (104608, 22)

# %%
power_data_west.dtypes
# Out:
# Unnamed: 0                  int64
# index_x                     int64
# service                    object
# start                      object
# end                datetime64[ns]
# usage                     float64
# cost                      float64
# temp                      float64
# event_flag                 object
# demand                    float64
# sfm                        object
# index_y                     int64
# dt                          int64
# dt_iso                     object
# humidity                    int64
# humidity_temp             float64
# pt_date                    object
# month                      object
# month_int                    Int8
# day_of_week                object
# day_of_week_int             int64
# holiday                      bool
# dtype: object

# %%
#For checking missing values in dataset
power_data_west.isna().sum()
# Out:
# Unnamed: 0              0
# index_x                 0
# service                 0
# start                   0
# end                     0
# usage                  12
# cost               104608
# temp                   20
# event_flag         104602
# demand                 12
# sfm                     0
# index_y                 0
# dt                      0
# dt_iso                  0
# humidity                0
# humidity_temp           0
# pt_date                 0
# month                   0
# month_int               0
# day_of_week             0
# day_of_week_int         0
# holiday                 0
# dtype: int64

# %%
power_data_west.fillna(method='ffill',inplace=True)
power_data_west.isna().sum()
# Out:
# Unnamed: 0              0
# index_x                 0
# service                 0
# start                   0
# end                     0
# usage                   0
# cost               104608
# temp                    0
# event_flag           3840
# demand                  0
# sfm                     0
# index_y                 0
# dt                      0
# dt_iso                  0
# humidity                0
# humidity_temp           0
# pt_date                 0
# month                   0
# month_int               0
# day_of_week             0
# day_of_week_int         0
# holiday                 0
# dtype: int64

# %%
zero_usage_df = power_data_west.loc[power_data_west['demand'] == 0]
zero_usage_df.count()
# Out:
# Unnamed: 0         50
# index_x            50
# service            50
# start              50
# end                50
# usage              50
# cost                0
# temp               50
# event_flag         50
# demand             50
# sfm                50
# index_y            50
# dt                 50
# dt_iso             50
# humidity           50
# humidity_temp      50
# pt_date            50
# month              50
# month_int          50
# day_of_week        50
# day_of_week_int    50
# holiday            50
# dtype: int64

# %%
power_data_west = power_data_west[power_data_west['demand'] != 0]
zero_usage_df = power_data_west.loc[power_data_west['demand'] == 0]
zero_usage_df.count()
# Out:
# Unnamed: 0         0
# index_x            0
# service            0
# start              0
# end                0
# usage              0
# cost               0
# temp               0
# event_flag         0
# demand             0
# sfm                0
# index_y            0
# dt                 0
# dt_iso             0
# humidity           0
# humidity_temp      0
# pt_date            0
# month              0
# month_int          0
# day_of_week        0
# day_of_week_int    0
# holiday            0
# dtype: int64

# %% [markdown]
# ## Linear Demand

# %%
linear_data = power_data_west[(power_data_west['end'] > '2019-01-01') & (power_data_west['end'] < '2022-02-01')]

# %%
linear_data["holiday_int"] = linear_data["holiday"].astype(int)

# %%
linear_data.head(10)
# Out:
#    Unnamed: 0  index_x service                start                 end  \
# 0           0        0    west  2019-01-29 00:00:00 2019-01-29 00:15:00
# 1           1        1    west  2019-01-29 00:15:00 2019-01-29 00:30:00
# 2           2        2    west  2019-01-29 00:30:00 2019-01-29 00:45:00
# 3           3        3    west  2019-01-29 00:45:00 2019-01-29 01:00:00
# 4           4        4    west  2019-01-29 01:00:00 2019-01-29 01:15:00
# 5           5        5    west  2019-01-29 01:15:00 2019-01-29 01:30:00
# 6           6        6    west  2019-01-29 01:30:00 2019-01-29 01:45:00
# 7           7        7    west  2019-01-29 01:45:00 2019-01-29 02:00:00
# 8           8        8    west  2019-01-29 02:00:00 2019-01-29 02:15:00
# 9           9        9    west  2019-01-29 02:15:00 2019-01-29 02:30:00
#
#    usage  cost  temp event_flag  demand  ...         dt_iso  humidity  \
# 0  211.2   NaN  54.0        NaN   844.8  ...  2019-01-29 08        21
# 1  210.4   NaN  54.0        NaN   841.6  ...  2019-01-29 08        21
# 2  208.0   NaN  54.0        NaN   832.0  ...  2019-01-29 08        21
# 3  212.0   NaN  54.0        NaN   848.0  ...  2019-01-29 08        21
# 4  203.2   NaN  55.0        NaN   812.8  ...  2019-01-29 09        21
# 5  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 6  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 7  208.8   NaN  55.0        NaN   835.2  ...  2019-01-29 09        21
# 8  217.6   NaN  55.0        NaN   870.4  ...  2019-01-29 10        22
# 9  229.6   NaN  55.0        NaN   918.4  ...  2019-01-29 10        22
#
#    humidity_temp        pt_date  month  month_int day_of_week day_of_week_int  \
# 0          63.86  2019-01-29 00    Jan          1     Tuesday               1
# 1          63.86  2019-01-29 00    Jan          1     Tuesday               1
# 2          63.86  2019-01-29 00    Jan          1     Tuesday               1
# 3          63.86  2019-01-29 00    Jan          1     Tuesday               1
# 4          63.41  2019-01-29 01    Jan          1     Tuesday               1
# 5          63.41  2019-01-29 01    Jan          1     Tuesday               1
# 6          63.41  2019-01-29 01    Jan          1     Tuesday               1
# 7          63.41  2019-01-29 01    Jan          1     Tuesday               1
# 8          62.98  2019-01-29 02    Jan          1     Tuesday               1
# 9          62.98  2019-01-29 02    Jan          1     Tuesday               1
#
#    holiday holiday_int
# 0    False           0
# 1    False           0
# 2    False           0
# 3    False           0
# 4    False           0
# 5    False           0
# 6    False           0
# 7    False           0
# 8    False           0
# 9    False           0
#
# [10 rows x 23 columns]

# %%
linear_data['demand'].plot()
# Out:
# <AxesSubplot:>

# %%
linear_data['temp'].plot()
# Out:
# <AxesSubplot:>

# %%
linear_data['humidity'].plot()
# Out:
# <AxesSubplot:>

# %%
linear_data_mod = linear_data[['demand', 'temp', 'humidity', 'month_int', 'day_of_week_int', 'holiday_int']].copy()

# %%
linear_data_mod.head(10)
# Out:
#    demand  temp  humidity  month_int  day_of_week_int  holiday_int
# 0   844.8  54.0        21          1                1            0
# 1   841.6  54.0        21          1                1            0
# 2   832.0  54.0        21          1                1            0
# 3   848.0  54.0        21          1                1            0
# 4   812.8  55.0        21          1                1            0
# 5   822.4  55.0        21          1                1            0
# 6   822.4  55.0        21          1                1            0
# 7   835.2  55.0        21          1                1            0
# 8   870.4  55.0        22          1                1            0
# 9   918.4  55.0        22          1                1            0

# %%
for i in range(1, 97):
    linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
    linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
    linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# Out:
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# ...
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["demand_lag_{}".format(i)] = linear_data_mod['demand'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["temp_lag_{}".format(i)] = linear_data_mod['temp'].shift(i)
# /var/folders/7y/xgxlym8j2wvcdq_3kmlw40zm0000gn/T/ipykernel_4128/863251574.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   linear_data_mod["humidity_lag_{}".format(i)] = linear_data_mod['humidity'].shift(i)

# %%
linear_data_mod.head(10)
# Out:
#    demand  temp  humidity  month_int  day_of_week_int  holiday_int  \
# 0   844.8  54.0        21          1                1            0
# 1   841.6  54.0        21          1                1            0
# 2   832.0  54.0        21          1                1            0
# 3   848.0  54.0        21          1                1            0
# 4   812.8  55.0        21          1                1            0
# 5   822.4  55.0        21          1                1            0
# 6   822.4  55.0        21          1                1            0
# 7   835.2  55.0        21          1                1            0
# 8   870.4  55.0        22          1                1            0
# 9   918.4  55.0        22          1                1            0
#
#    demand_lag_1  temp_lag_1  humidity_lag_1  demand_lag_2  ...  \
# 0           NaN         NaN             NaN           NaN  ...
# 1         844.8        54.0            21.0           NaN  ...
# 2         841.6        54.0            21.0         844.8  ...
# 3         832.0        54.0            21.0         841.6  ...
# 4         848.0        54.0            21.0         832.0  ...
# 5         812.8        55.0            21.0         848.0  ...
# 6         822.4        55.0            21.0         812.8  ...
# 7         822.4        55.0            21.0         822.4  ...
# 8         835.2        55.0            21.0         822.4  ...
# 9         870.4        55.0            22.0         835.2  ...
#
#    humidity_lag_956  demand_lag_957  temp_lag_957  humidity_lag_957  \
# 0               NaN             NaN           NaN               NaN
# 1               NaN             NaN           NaN               NaN
# 2               NaN             NaN           NaN               NaN
# 3               NaN             NaN           NaN               NaN
# 4               NaN             NaN           NaN               NaN
# 5               NaN             NaN           NaN               NaN
# 6               NaN             NaN           NaN               NaN
# 7               NaN             NaN           NaN               NaN
# 8               NaN             NaN           NaN               NaN
# 9               NaN             NaN           NaN               NaN
#
#    demand_lag_958  temp_lag_958  humidity_lag_958  demand_lag_959  \
# 0             NaN           NaN               NaN             NaN
# 1             NaN           NaN               NaN             NaN
# 2             NaN           NaN               NaN             NaN
# 3             NaN           NaN               NaN             NaN
# 4             NaN           NaN               NaN             NaN
# 5             NaN           NaN               NaN             NaN
# 6             NaN           NaN               NaN             NaN
# 7             NaN           NaN               NaN             NaN
# 8             NaN           NaN               NaN             NaN
# 9             NaN           NaN               NaN             NaN
#
#    temp_lag_959  humidity_lag_959
# 0           NaN               NaN
# 1           NaN               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN
# 5           NaN               NaN
# 6           NaN               NaN
# 7           NaN               NaN
# 8           NaN               NaN
# 9           NaN               NaN
#
# [10 rows x 2883 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
def timeseries_train_test_split(X, y, test_size):
    
    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))
    
    X_train = X.iloc[:test_index]
    y_train = y.iloc[:test_index]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]
    
    return X_train, X_test, y_train, y_test

# %%
y = linear_data_mod.dropna()['demand']
X = linear_data_mod.dropna().drop(['demand', 'temp', 'humidity'], axis=1)

# %%
X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (72519, 2880)

# %%
y_train.shape
# Out:
# (72519,)

# %%
X_test.shape
# Out:
# (31080, 2880)

# %%
y_test.shape
# Out:
# (31080,)

# %%
lr = LinearRegression(fit_intercept=True)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
def plotModelTrainingResults(model, X_train=X_train, X_test=X_test):
  
    prediction = model.predict(X_train)
    
    plt.figure(figsize=(15, 10))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_train.values, label="actual", linewidth=2.0, alpha=0.5)

    mape_error_var = mean_absolute_percentage_error(y_train, prediction)
    mae_error_var = mean_absolute_error(y_train, prediction)
    mse_error_var = mean_squared_error(y_train, prediction, squared=True)
    rmse_error_var = mean_squared_error(y_train, prediction, squared=False)
    
    plt.title("Mean absolute percentage error {0:.2f}%".format(mape_error_var))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
    results = pd.DataFrame({'Actual':y_train, 
                            'Prediction':prediction  
                           })
    
    return results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var
    
train_results, train_mape_error_var, train_mae_error_var, train_mse_error_var, train_rmse_error_var = plotModelTrainingResults(lr)

# %%
train_results['residual'] = train_results['Actual'] - train_results['Prediction']

# %%
train_results.tail(10)
# Out:
#        Actual   Prediction    residual
# 73484  1318.4  1298.212710   20.187290
# 73485  1318.4  1312.209686    6.190314
# 73486  1331.2  1298.187719   33.012281
# 73487  1270.4  1330.314387  -59.914387
# 73488  1340.8  1289.558186   51.241814
# 73489  1356.8  1328.378583   28.421417
# 73490  1340.8  1352.038439  -11.238439
# 73491  1379.2  1354.955423   24.244577
# 73492  1433.6  1380.977731   52.622269
# 73493  1257.6  1393.054447 -135.454447

# %%
train_results['residual'].plot()
# Out:
# <AxesSubplot:>

# %%
train_results['residual'].hist()
plt.show()

# %%
# autocorrelation
autocorrelation_plot(train_results['residual'])
plt.show()

# %%
print('MAPE: ' , train_mape_error_var)
print('MAE: ', train_mae_error_var)
print('MSE: ', train_mse_error_var)
print('RMSE: ', train_rmse_error_var)
# Out:
# MAPE:  0.026593442401374005
# MAE:  26.71625351929964
# MSE:  1415.7581449960671
# RMSE:  37.62656169511197

# %%
def plotModelPredictions(model, X_train=X_train, X_test=X_test):
  
    prediction = model.predict(X_test)
    
    plt.figure(figsize=(15, 10))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_test.values, label="actual", linewidth=2.0, alpha=0.5)

    mape_error_var = mean_absolute_percentage_error(y_test,prediction)
    mae_error_var = mean_absolute_error(y_test,prediction)
    mse_error_var = mean_squared_error(y_test,prediction, squared=True)
    rmse_error_var = mean_squared_error(y_test,prediction, squared=False)
    
    plt.title("Mean absolute percentage error {0:.2f}%".format(mae_error_var))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
    results = pd.DataFrame({'Actual':y_test, 
                            'Prediction':prediction  
                           })
    
    return results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var
    
results, mape_error_var, mae_error_var, mse_error_var, rmse_error_var = plotModelPredictions(lr)

# %%
results['residual'] = results['Actual'] - results['Prediction']

# %%
results.tail(10)
# Out:
#         Actual   Prediction   residual
# 104598  1206.4  1222.026043 -15.626043
# 104599  1200.0  1195.284720   4.715280
# 104600  1203.2  1215.471094 -12.271094
# 104601  1238.4  1203.110026  35.289974
# 104602  1190.4  1236.511959 -46.111959
# 104603  1190.4  1206.450109 -16.050109
# 104604  1180.8  1199.659766 -18.859766
# 104605  1219.2  1184.593952  34.606048
# 104606  1238.4  1219.888330  18.511670
# 104607  1187.2  1229.977243 -42.777243

# %%
results['residual'].plot()
# Out:
# <AxesSubplot:>

# %%
results['residual'].hist()
plt.show()

# %%
autocorrelation_plot(results['residual'])
plt.show()

# %%
print('MAPE: ' , mape_error_var)
print('MAE: ', mae_error_var)
print('MSE: ', mse_error_var)
print('RMSE: ', rmse_error_var)
# Out:
# MAPE:  1.7063360913918577
# MAE:  31.966784840423276
# MSE:  2395.899703968099
# RMSE:  48.9479284951682

# %%
def plotCoefficients(model, maxDisplayValues=50):
    
    coefs = pd.DataFrame(model.coef_, X_train.columns)
    coefs.columns = ["coef"]
    coefs["abs"] = coefs.coef.apply(np.abs)
    coefs = coefs.sort_values(by="abs", ascending=False).drop(["abs"], axis=1)
    plot_coefs = coefs.head(maxDisplayValues)
    
    plt.figure(figsize=(15, 7))
    plot_coefs.coef.plot(kind='bar')
    plt.grid(True, axis='y')
    plt.hlines(y=0, xmin=0, xmax=len(plot_coefs), linestyles='dashed');

plotCoefficients(lr)

# %%
import joblib
joblib.dump(lr, "./linear_model_15m.joblib")
