# %% [markdown]
#  # Power Load Prediction for West Zone - GRU Model

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
power_data_west = pd.read_csv("westdata_augmented.csv")
# Out:
# /var/folders/dp/hc18q34s725bvgbbqb8yj1l80000gn/T/ipykernel_56002/1727164072.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   power_data_west = pd.read_csv("westdata_augmented.csv")

# %%
power_data_west['end'] = pd.to_datetime(power_data_west['end'], infer_datetime_format=True)
indexedDataset = power_data_west.set_index(['end'])

# %%
plot_df_west = pd.DataFrame(power_data_west, columns=['demand', 'temp', 'end', 'humidity'])

# %%
plot_df_west['end'].min()
# Out:
# Timestamp('2019-01-29 00:15:00')

# %%
plot_df_west['end'].max()
# Out:
# Timestamp('2022-01-25 16:00:00')

# %%
power_data_west['month'] = power_data_west['end'].dt.strftime('%b')

# %%
from calendar import month_abbr

lower_ma = [m.lower() for m in month_abbr]

# one-liner with Pandas
power_data_west['month_int'] = power_data_west['month'].str.lower().map(lambda m: lower_ma.index(m)).astype('Int8')

# %%
power_data_west['day_of_week'] = power_data_west['end'].dt.day_name()

# %%
power_data_west['day_of_week_int'] = power_data_west['end'].dt.strftime("%w")

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

date_range = pd.date_range(start='2019-01-01', end='2022-01-27')

cal = calendar()
holidays = cal.holidays(start=date_range.min(), end=date_range.max())

power_data_west['holiday'] = power_data_west['end'].dt.date.astype('datetime64').isin(holidays)

# %%
power_data_west["holiday_int"] = power_data_west["holiday"].astype(int)

# %%
power_data_west.head(10)
# Out:
#    Unnamed: 0  index_x service                start                 end  \
# 0           0        0    west  2019-01-29 00:00:00 2019-01-29 00:15:00
# 1           1        1    west  2019-01-29 00:15:00 2019-01-29 00:30:00
# 2           2        2    west  2019-01-29 00:30:00 2019-01-29 00:45:00
# 3           3        3    west  2019-01-29 00:45:00 2019-01-29 01:00:00
# 4           4        4    west  2019-01-29 01:00:00 2019-01-29 01:15:00
# 5           5        5    west  2019-01-29 01:15:00 2019-01-29 01:30:00
# 6           6        6    west  2019-01-29 01:30:00 2019-01-29 01:45:00
# 7           7        7    west  2019-01-29 01:45:00 2019-01-29 02:00:00
# 8           8        8    west  2019-01-29 02:00:00 2019-01-29 02:15:00
# 9           9        9    west  2019-01-29 02:15:00 2019-01-29 02:30:00
#
#    usage  cost  temp event_flag  demand  ...         dt_iso  humidity  \
# 0  211.2   NaN  54.0        NaN   844.8  ...  2019-01-29 08        21
# 1  210.4   NaN  54.0        NaN   841.6  ...  2019-01-29 08        21
# 2  208.0   NaN  54.0        NaN   832.0  ...  2019-01-29 08        21
# 3  212.0   NaN  54.0        NaN   848.0  ...  2019-01-29 08        21
# 4  203.2   NaN  55.0        NaN   812.8  ...  2019-01-29 09        21
# 5  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 6  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 7  208.8   NaN  55.0        NaN   835.2  ...  2019-01-29 09        21
# 8  217.6   NaN  55.0        NaN   870.4  ...  2019-01-29 10        22
# 9  229.6   NaN  55.0        NaN   918.4  ...  2019-01-29 10        22
#
#    humidity_temp        pt_date  month  month_int day_of_week day_of_week_int  \
# 0          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 1          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 2          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 3          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 4          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 5          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 6          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 7          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 8          62.98  2019-01-29 02    Jan          1     Tuesday               2
# 9          62.98  2019-01-29 02    Jan          1     Tuesday               2
#
#    holiday holiday_int
# 0    False           0
# 1    False           0
# 2    False           0
# 3    False           0
# 4    False           0
# 5    False           0
# 6    False           0
# 7    False           0
# 8    False           0
# 9    False           0
#
# [10 rows x 23 columns]

# %%
power_data_west.tail(10)
# Out:
#         Unnamed: 0  index_x service                start                 end  \
# 104598      104598   104598    west  2022-01-25 13:30:00 2022-01-25 13:45:00
# 104599      104599   104599    west  2022-01-25 13:45:00 2022-01-25 14:00:00
# 104600      104600   104600    west  2022-01-25 14:00:00 2022-01-25 14:15:00
# 104601      104601   104601    west  2022-01-25 14:15:00 2022-01-25 14:30:00
# 104602      104602   104602    west  2022-01-25 14:30:00 2022-01-25 14:45:00
# 104603      104603   104603    west  2022-01-25 14:45:00 2022-01-25 15:00:00
# 104604      104604   104604    west  2022-01-25 15:00:00 2022-01-25 15:15:00
# 104605      104605   104605    west  2022-01-25 15:15:00 2022-01-25 15:30:00
# 104606      104606   104606    west  2022-01-25 15:30:00 2022-01-25 15:45:00
# 104607      104607   104607    west  2022-01-25 15:45:00 2022-01-25 16:00:00
#
#         usage  cost  temp event_flag  demand  ...         dt_iso  humidity  \
# 104598  301.6   NaN  66.0        NaN  1206.4  ...  2022-01-25 21        37
# 104599  300.0   NaN  66.0        NaN  1200.0  ...  2022-01-25 21        37
# 104600  300.8   NaN  67.0        NaN  1203.2  ...  2022-01-25 22        27
# 104601  309.6   NaN  67.0        NaN  1238.4  ...  2022-01-25 22        27
# 104602  297.6   NaN  67.0        NaN  1190.4  ...  2022-01-25 22        27
# 104603  297.6   NaN  67.0        NaN  1190.4  ...  2022-01-25 22        27
# 104604  295.2   NaN  67.0        NaN  1180.8  ...  2022-01-25 23        26
# 104605  304.8   NaN  67.0        NaN  1219.2  ...  2022-01-25 23        26
# 104606  309.6   NaN  67.0        NaN  1238.4  ...  2022-01-25 23        26
# 104607  296.8   NaN  67.0        NaN  1187.2  ...  2022-01-25 23        26
#
#         humidity_temp        pt_date  month  month_int day_of_week  \
# 104598          68.23  2022-01-25 13    Jan          1     Tuesday
# 104599          68.23  2022-01-25 13    Jan          1     Tuesday
# 104600          69.22  2022-01-25 14    Jan          1     Tuesday
# 104601          69.22  2022-01-25 14    Jan          1     Tuesday
# 104602          69.22  2022-01-25 14    Jan          1     Tuesday
# 104603          69.22  2022-01-25 14    Jan          1     Tuesday
# 104604          68.34  2022-01-25 15    Jan          1     Tuesday
# 104605          68.34  2022-01-25 15    Jan          1     Tuesday
# 104606          68.34  2022-01-25 15    Jan          1     Tuesday
# 104607          68.34  2022-01-25 15    Jan          1     Tuesday
#
#        day_of_week_int  holiday holiday_int
# 104598               2    False           0
# 104599               2    False           0
# 104600               2    False           0
# 104601               2    False           0
# 104602               2    False           0
# 104603               2    False           0
# 104604               2    False           0
# 104605               2    False           0
# 104606               2    False           0
# 104607               2    False           0
#
# [10 rows x 23 columns]

# %%
power_data_west.describe()
# Out:
#           Unnamed: 0        index_x          usage  cost          temp  \
# count  104608.000000  104608.000000  104596.000000   0.0  104588.00000
# mean    52303.500000   52303.500000     309.658615   NaN      67.39232
# std     30197.872817   30197.872817      75.599852   NaN      16.59371
# min         0.000000       0.000000       0.000000   NaN      29.00000
# 25%     26151.750000   26151.750000     252.000000   NaN      54.00000
# 50%     52303.500000   52303.500000     308.000000   NaN      66.00000
# 75%     78455.250000   78455.250000     368.000000   NaN      79.00000
# max    104607.000000  104607.000000     531.200000   NaN     114.00000
#
#               demand        index_y            dt       humidity  \
# count  104596.000000  104608.000000  1.046080e+05  104608.000000
# mean     1238.634456   13764.530284  1.595853e+09      52.635401
# std       302.399419    7560.847033  2.721905e+07      22.815913
# min         0.000000     680.000000  1.548749e+09       3.000000
# 25%      1008.000000    7217.750000  1.572285e+09      34.000000
# 50%      1232.000000   13755.500000  1.595821e+09      49.000000
# 75%      1472.000000   20317.250000  1.619443e+09      70.000000
# max      2124.800000   26903.000000  1.643152e+09     100.000000
#
#        humidity_temp     month_int    holiday_int
# count  104608.000000  104608.00000  104608.000000
# mean       68.527903       6.54298       0.028449
# std        15.741494       3.43464       0.166253
# min        32.200000       1.00000       0.000000
# 25%        55.850000       4.00000       0.000000
# 50%        66.900000       7.00000       0.000000
# 75%        80.550000      10.00000       0.000000
# max       110.680000      12.00000       1.000000

# %%
power_data_west.shape
# Out:
# (104608, 23)

# %%
power_data_west.dtypes
# Out:
# Unnamed: 0                  int64
# index_x                     int64
# service                    object
# start                      object
# end                datetime64[ns]
# usage                     float64
# cost                      float64
# temp                      float64
# event_flag                 object
# demand                    float64
# sfm                        object
# index_y                     int64
# dt                          int64
# dt_iso                     object
# humidity                    int64
# humidity_temp             float64
# pt_date                    object
# month                      object
# month_int                    Int8
# day_of_week                object
# day_of_week_int            object
# holiday                      bool
# holiday_int                 int64
# dtype: object

# %%
#For checking missing values in dataset
power_data_west.isna().sum()
# Out:
# Unnamed: 0              0
# index_x                 0
# service                 0
# start                   0
# end                     0
# usage                  12
# cost               104608
# temp                   20
# event_flag         104602
# demand                 12
# sfm                     0
# index_y                 0
# dt                      0
# dt_iso                  0
# humidity                0
# humidity_temp           0
# pt_date                 0
# month                   0
# month_int               0
# day_of_week             0
# day_of_week_int         0
# holiday                 0
# holiday_int             0
# dtype: int64

# %%
power_data_west.fillna(method='ffill',inplace=True)
power_data_west.isna().sum()
# Out:
# Unnamed: 0              0
# index_x                 0
# service                 0
# start                   0
# end                     0
# usage                   0
# cost               104608
# temp                    0
# event_flag           3840
# demand                  0
# sfm                     0
# index_y                 0
# dt                      0
# dt_iso                  0
# humidity                0
# humidity_temp           0
# pt_date                 0
# month                   0
# month_int               0
# day_of_week             0
# day_of_week_int         0
# holiday                 0
# holiday_int             0
# dtype: int64

# %%
zero_usage_df = power_data_west.loc[power_data_west['demand'] == 0]
zero_usage_df.count()
# Out:
# Unnamed: 0         50
# index_x            50
# service            50
# start              50
# end                50
# usage              50
# cost                0
# temp               50
# event_flag         50
# demand             50
# sfm                50
# index_y            50
# dt                 50
# dt_iso             50
# humidity           50
# humidity_temp      50
# pt_date            50
# month              50
# month_int          50
# day_of_week        50
# day_of_week_int    50
# holiday            50
# holiday_int        50
# dtype: int64

# %%
power_data_west = power_data_west[power_data_west['demand'] != 0]
zero_usage_df = power_data_west.loc[power_data_west['demand'] == 0]
zero_usage_df.count()
# Out:
# Unnamed: 0         0
# index_x            0
# service            0
# start              0
# end                0
# usage              0
# cost               0
# temp               0
# event_flag         0
# demand             0
# sfm                0
# index_y            0
# dt                 0
# dt_iso             0
# humidity           0
# humidity_temp      0
# pt_date            0
# month              0
# month_int          0
# day_of_week        0
# day_of_week_int    0
# holiday            0
# holiday_int        0
# dtype: int64

# %% [markdown]
# dataset.kW.plot()

# %% [markdown]
# ## GRU Timeseries Model

# %%
gru_data = power_data_west[(power_data_west['end'] > '2019-01-01') & (power_data_west['end'] < '2022-02-01')]

# %%
gru_data.head(10)
# Out:
#    Unnamed: 0  index_x service                start                 end  \
# 0           0        0    west  2019-01-29 00:00:00 2019-01-29 00:15:00
# 1           1        1    west  2019-01-29 00:15:00 2019-01-29 00:30:00
# 2           2        2    west  2019-01-29 00:30:00 2019-01-29 00:45:00
# 3           3        3    west  2019-01-29 00:45:00 2019-01-29 01:00:00
# 4           4        4    west  2019-01-29 01:00:00 2019-01-29 01:15:00
# 5           5        5    west  2019-01-29 01:15:00 2019-01-29 01:30:00
# 6           6        6    west  2019-01-29 01:30:00 2019-01-29 01:45:00
# 7           7        7    west  2019-01-29 01:45:00 2019-01-29 02:00:00
# 8           8        8    west  2019-01-29 02:00:00 2019-01-29 02:15:00
# 9           9        9    west  2019-01-29 02:15:00 2019-01-29 02:30:00
#
#    usage  cost  temp event_flag  demand  ...         dt_iso  humidity  \
# 0  211.2   NaN  54.0        NaN   844.8  ...  2019-01-29 08        21
# 1  210.4   NaN  54.0        NaN   841.6  ...  2019-01-29 08        21
# 2  208.0   NaN  54.0        NaN   832.0  ...  2019-01-29 08        21
# 3  212.0   NaN  54.0        NaN   848.0  ...  2019-01-29 08        21
# 4  203.2   NaN  55.0        NaN   812.8  ...  2019-01-29 09        21
# 5  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 6  205.6   NaN  55.0        NaN   822.4  ...  2019-01-29 09        21
# 7  208.8   NaN  55.0        NaN   835.2  ...  2019-01-29 09        21
# 8  217.6   NaN  55.0        NaN   870.4  ...  2019-01-29 10        22
# 9  229.6   NaN  55.0        NaN   918.4  ...  2019-01-29 10        22
#
#    humidity_temp        pt_date  month  month_int day_of_week day_of_week_int  \
# 0          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 1          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 2          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 3          63.86  2019-01-29 00    Jan          1     Tuesday               2
# 4          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 5          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 6          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 7          63.41  2019-01-29 01    Jan          1     Tuesday               2
# 8          62.98  2019-01-29 02    Jan          1     Tuesday               2
# 9          62.98  2019-01-29 02    Jan          1     Tuesday               2
#
#    holiday holiday_int
# 0    False           0
# 1    False           0
# 2    False           0
# 3    False           0
# 4    False           0
# 5    False           0
# 6    False           0
# 7    False           0
# 8    False           0
# 9    False           0
#
# [10 rows x 23 columns]

# %%
gru_data.tail(10)
# Out:
#         Unnamed: 0  index_x service                start                 end  \
# 104598      104598   104598    west  2022-01-25 13:30:00 2022-01-25 13:45:00
# 104599      104599   104599    west  2022-01-25 13:45:00 2022-01-25 14:00:00
# 104600      104600   104600    west  2022-01-25 14:00:00 2022-01-25 14:15:00
# 104601      104601   104601    west  2022-01-25 14:15:00 2022-01-25 14:30:00
# 104602      104602   104602    west  2022-01-25 14:30:00 2022-01-25 14:45:00
# 104603      104603   104603    west  2022-01-25 14:45:00 2022-01-25 15:00:00
# 104604      104604   104604    west  2022-01-25 15:00:00 2022-01-25 15:15:00
# 104605      104605   104605    west  2022-01-25 15:15:00 2022-01-25 15:30:00
# 104606      104606   104606    west  2022-01-25 15:30:00 2022-01-25 15:45:00
# 104607      104607   104607    west  2022-01-25 15:45:00 2022-01-25 16:00:00
#
#         usage  cost  temp        event_flag  demand  ...         dt_iso  \
# 104598  301.6   NaN  66.0  Daylight Savings  1206.4  ...  2022-01-25 21
# 104599  300.0   NaN  66.0  Daylight Savings  1200.0  ...  2022-01-25 21
# 104600  300.8   NaN  67.0  Daylight Savings  1203.2  ...  2022-01-25 22
# 104601  309.6   NaN  67.0  Daylight Savings  1238.4  ...  2022-01-25 22
# 104602  297.6   NaN  67.0  Daylight Savings  1190.4  ...  2022-01-25 22
# 104603  297.6   NaN  67.0  Daylight Savings  1190.4  ...  2022-01-25 22
# 104604  295.2   NaN  67.0  Daylight Savings  1180.8  ...  2022-01-25 23
# 104605  304.8   NaN  67.0  Daylight Savings  1219.2  ...  2022-01-25 23
# 104606  309.6   NaN  67.0  Daylight Savings  1238.4  ...  2022-01-25 23
# 104607  296.8   NaN  67.0  Daylight Savings  1187.2  ...  2022-01-25 23
#
#         humidity  humidity_temp        pt_date  month  month_int day_of_week  \
# 104598        37          68.23  2022-01-25 13    Jan          1     Tuesday
# 104599        37          68.23  2022-01-25 13    Jan          1     Tuesday
# 104600        27          69.22  2022-01-25 14    Jan          1     Tuesday
# 104601        27          69.22  2022-01-25 14    Jan          1     Tuesday
# 104602        27          69.22  2022-01-25 14    Jan          1     Tuesday
# 104603        27          69.22  2022-01-25 14    Jan          1     Tuesday
# 104604        26          68.34  2022-01-25 15    Jan          1     Tuesday
# 104605        26          68.34  2022-01-25 15    Jan          1     Tuesday
# 104606        26          68.34  2022-01-25 15    Jan          1     Tuesday
# 104607        26          68.34  2022-01-25 15    Jan          1     Tuesday
#
#        day_of_week_int  holiday holiday_int
# 104598               2    False           0
# 104599               2    False           0
# 104600               2    False           0
# 104601               2    False           0
# 104602               2    False           0
# 104603               2    False           0
# 104604               2    False           0
# 104605               2    False           0
# 104606               2    False           0
# 104607               2    False           0
#
# [10 rows x 23 columns]

# %%
gru_data_mod = gru_data[['demand', 'temp', 'humidity', 'month_int', 'day_of_week_int', 'holiday_int']].copy()

# %%
gru_data_mod.head(10)
# Out:
#    demand  temp  humidity  month_int day_of_week_int  holiday_int
# 0   844.8  54.0        21          1               2            0
# 1   841.6  54.0        21          1               2            0
# 2   832.0  54.0        21          1               2            0
# 3   848.0  54.0        21          1               2            0
# 4   812.8  55.0        21          1               2            0
# 5   822.4  55.0        21          1               2            0
# 6   822.4  55.0        21          1               2            0
# 7   835.2  55.0        21          1               2            0
# 8   870.4  55.0        22          1               2            0
# 9   918.4  55.0        22          1               2            0

# %%
gru_data_mod.tail(10)
# Out:
#         demand  temp  humidity  month_int day_of_week_int  holiday_int
# 104598  1206.4  66.0        37          1               2            0
# 104599  1200.0  66.0        37          1               2            0
# 104600  1203.2  67.0        27          1               2            0
# 104601  1238.4  67.0        27          1               2            0
# 104602  1190.4  67.0        27          1               2            0
# 104603  1190.4  67.0        27          1               2            0
# 104604  1180.8  67.0        26          1               2            0
# 104605  1219.2  67.0        26          1               2            0
# 104606  1238.4  67.0        26          1               2            0
# 104607  1187.2  67.0        26          1               2            0

# %%
gru_timestep_data = gru_data_mod.copy()
gru_timestep_data.head(12)
# Out:
#     demand  temp  humidity  month_int day_of_week_int  holiday_int
# 0    844.8  54.0        21          1               2            0
# 1    841.6  54.0        21          1               2            0
# 2    832.0  54.0        21          1               2            0
# 3    848.0  54.0        21          1               2            0
# 4    812.8  55.0        21          1               2            0
# 5    822.4  55.0        21          1               2            0
# 6    822.4  55.0        21          1               2            0
# 7    835.2  55.0        21          1               2            0
# 8    870.4  55.0        22          1               2            0
# 9    918.4  55.0        22          1               2            0
# 10   905.6  55.0        22          1               2            0
# 11   867.2  55.0        22          1               2            0

# %%
from numpy import array
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    #print('Len >> ', len(sequences))
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        #print(end_ix)
        # check if we are beyond the dataset
        if end_ix+1 >= len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, 0:6], sequences[end_ix, 0]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
X,y = split_sequences(gru_timestep_data.to_numpy(), 960)

# %%
X.shape
# Out:
# (103597, 960, 6)

# %%
y.shape
# Out:
# (103597,)

# %%
X = X.reshape((103597, 5760))

# %%
from sklearn.preprocessing import MinMaxScaler

n_train_hours = 2 * 365 * 24 * 4
X_train = X[:n_train_hours, :]
X_test = X[n_train_hours:, :]

y_train = y[:n_train_hours]
y_test = y[n_train_hours:]

X_scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

y_scaler = MinMaxScaler(feature_range=(0, 1))
y_train_np= y_train.reshape((y_train.shape[0],1))
y_train_scaled = y_scaler.fit_transform(y_train_np)

y_test_np= y_test.reshape((y_test.shape[0],1))
y_test_scaled = y_scaler.transform(y_test_np)

# reshape input to be 3D [samples, timesteps, features]
X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 960, 6))
X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 960, 6))
print(X_train_scaled.shape, y_train_scaled.shape, X_test_scaled.shape, y_test_scaled.shape)
# Out:
# (70080, 960, 6) (70080, 1) (33517, 960, 6) (33517, 1)

# %%
#exporting the departure encoder
output = open('gru_X_standardscalar-15m.pkl', 'wb')
pickle.dump(X_scaler, output)
output.close()

#exporting the departure encoder
output = open('gru_y_standardscalar-15m.pkl', 'wb')
pickle.dump(y_scaler, output)
output.close()

# %%
y_train
# Out:
# array([ 780.8,  768. ,  726.4, ..., 1212.8, 1209.6, 1193.6])

# %%
y_test
# Out:
# array([1225.6, 1200. , 1177.6, ..., 1180.8, 1219.2, 1238.4])

# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from pylab import rcParams
from matplotlib import rc
from keras.callbacks import ModelCheckpoint

# design network
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.GRU(200, activation='relu', 
                              return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
model.add(tf.keras.layers.GRU(100, activation='relu') )
model.add(tf.keras.layers.Dense(1))

model.load_weights("grumodel_15m_best.hdf5")

model.compile(loss='mae', optimizer='adam')

filepath="grumodel_15m_best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# fit network
history = model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=100, 
                    validation_data=(X_test_scaled, y_test_scaled), verbose=2, shuffle=False, callbacks=callbacks_list)
# Out:
# Using TensorFlow backend.
# [2022-03-30 19:24:27.940 ip-172-16-106-203:23481 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-03-30 19:24:27.965 ip-172-16-106-203:23481 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Train on 70080 samples, validate on 33517 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 0.03173, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5452s - loss: 0.0154 - val_loss: 0.0317
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 0.03173 to 0.02294, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5451s - loss: 0.0156 - val_loss: 0.0229
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 0.02294 to 0.02117, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5439s - loss: 0.0153 - val_loss: 0.0212
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 0.02117 to 0.01876, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5466s - loss: 0.0154 - val_loss: 0.0188
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 0.01876 to 0.01750, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5482s - loss: 0.0154 - val_loss: 0.0175
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 0.01750 to 0.01733, saving model to grumodel_15m_best.hdf5
# 70080/70080 - 5465s - loss: 0.0153 - val_loss: 0.0173
# Epoch 7/10

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from pylab import rcParams
from matplotlib import rc
from keras.callbacks import ModelCheckpoint

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.GRU(200, activation='relu', return_sequences=True, 
                              input_shape=(960, 6)))
model.add(tf.keras.layers.GRU(100, activation='relu') )
model.add(tf.keras.layers.Dense(1))

model.load_weights("grumodel_15m_best_final.hdf5")

model.compile(loss='mae', optimizer='adam')

model.summary()
# Out:
# 2022-04-10 10:12:53.655673: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 960, 200)          124800
#
#  gru_1 (GRU)                 (None, 100)               90600
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 215,501
# Trainable params: 215,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(X_test_scaled, y_test_scaled, verbose=1)
# Out:
# 33517/33517 [==============================] - 1500s 45ms/sample - loss: 0.0173
# 0.017328983781578135

# %%
# prediction on trainset
print('Running Prediction')
y_pred_train = model.predict(X_train_scaled)
print('Done')
# Out:
# Running Prediction

# %%
y_pred_train.shape
# Out:
# (70080, 1)

# %%
inv_y_pred_train=  y_scaler.inverse_transform(y_pred_train)
inv_y_pred_train.shape
# Out:
# (70080, 1)

# %%
final_train_df = pd.concat([pd.DataFrame(y_train, columns = ['Actual Peak Demand']), pd.DataFrame(inv_y_pred_train, columns = ['Predicted Peak Demand'])], axis=1)
final_train_df
# Out:
#        Actual Peak Demand  Predicted Peak Demand
# 0                   780.8             843.563171
# 1                   768.0             827.317932
# 2                   726.4             815.075195
# 3                   742.4             780.473206
# 4                   742.4             790.929504
# ...                   ...                    ...
# 70075              1193.6            1206.770508
# 70076              1235.2            1226.038208
# 70077              1212.8            1252.173950
# 70078              1209.6            1236.663574
# 70079              1193.6            1235.953491
#
# [70080 rows x 2 columns]

# %%
final_train_df.to_csv('15m_GRU_Model_Train_Results.csv')

# %%
train_mean_absolute_error_var = mean_absolute_error(final_train_df['Actual Peak Demand'], final_train_df['Predicted Peak Demand'])
train_mean_absolute_percentage_error_var = mean_absolute_percentage_error(final_train_df['Actual Peak Demand'], final_train_df['Predicted Peak Demand'])
train_mse_error_var = mean_squared_error(final_train_df['Actual Peak Demand'], final_train_df['Predicted Peak Demand'], squared=True)
train_rmse_error_var = mean_squared_error(final_train_df['Actual Peak Demand'], final_train_df['Predicted Peak Demand'], squared=False)

# %%
print('Train Set Metrics')
print('MAE: ' , train_mean_absolute_error_var)
print('MAPE: ', train_mean_absolute_percentage_error_var)
print('MSE: ', train_mse_error_var)
print('RMSE: ', train_rmse_error_var)
# Out:
# Train Set Metrics
# MAE:  33.25759862088504
# MAPE:  0.03356547779029653
# MSE:  1971.3971520971495
# RMSE:  44.40041837750124

# %%
# make a prediction
print('Running Prediction')
y_pred = model.predict(X_test_scaled)
print('Done')
# Out:
# Running Prediction
# Done

# %%
y_pred.shape
# Out:
# (33517, 1)

# %%
y_pred
# Out:
# array([[0.6142497 ],
#        [0.6266612 ],
#        [0.6160872 ],
#        ...,
#        [0.617166  ],
#        [0.6107145 ],
#        [0.62591153]], dtype=float32)

# %%
inv_y_pred=  y_scaler.inverse_transform(y_pred)
inv_y_pred.shape
# Out:
# (33517, 1)

# %%
final_df = pd.concat([pd.DataFrame(y_test, columns = ['Actual Peak Demand']), pd.DataFrame(inv_y_pred, columns = ['Predicted Peak Demand'])], axis=1)
final_df
# Out:
#        Actual Peak Demand  Predicted Peak Demand
# 0                  1225.6            1221.871460
# 1                  1200.0            1246.495728
# 2                  1177.6            1225.516968
# 3                  1171.2            1211.988892
# 4                  1164.8            1202.965820
# ...                   ...                    ...
# 33512              1190.4            1261.276733
# 33513              1190.4            1225.079712
# 33514              1180.8            1227.657349
# 33515              1219.2            1214.857544
# 33516              1238.4            1245.008423
#
# [33517 rows x 2 columns]

# %%
final_df.to_csv('15m_GRU_Model_Test_Results.csv')

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_error_var = mean_absolute_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mean_absolute_percentage_error_var = mean_absolute_percentage_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'])
mse_error_var = mean_squared_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'], squared=True)
rmse_error_var = mean_squared_error(final_df['Actual Peak Demand'], final_df['Predicted Peak Demand'], squared=False)

# %%
print('Test Set Metrics')
print('MAPE: ' , mean_absolute_percentage_error_var)
print('MAE: ', mean_absolute_error_var)
print('MSE: ', mse_error_var)
print('RMSE: ', rmse_error_var)
# Out:
# Test Set Metrics
# MAPE:  1.6841926532551763
# MAE:  34.38070367155209
# MSE:  2513.548655971599
# RMSE:  50.13530348937363

# %%
final_df.plot()
# Out:
# <AxesSubplot:>

# %%
final_df.head(96).plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train),  len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train),  len(y_train) + len(y_test)), inv_y_pred, 'r', label="prediction")
plt.ylabel('Peak Load')
plt.xlabel('Time Step')
plt.legend()
plt.show();
